# %%
# %matplotlib inline

from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.ensemble import RandomForestClassifier

import shap

# %%
shap.__version__
# Out:
# '0.29.3'

# %% [markdown]
# # Readme
# With this notebook:
# - Read the fasta files containing the sequences' DNAs and the excel files containing their metadata.
# - Clean the data.
# - Turn it into "one-hot encoded" data.
# - Save it to csv and pkl.

# %% [markdown]
# ### NHP Sequence alignment files (.aln format)

# %% [markdown]
# Put the files names (relative paths) in a list.
#
# We will iterate over this list to read the sequences into dataframes.

# %%
file_1 = '../DATA/!CLEAN/2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs'

file_2 = '../DATA/!CLEAN/NHP_65_outbreak'

file_3 = '../DATA/!CLEAN/2018-01_Salvador'

file_4 = '../DATA/!CLEAN/2018-03-04_LACEN_Bahia'

file_5 = '../DATA/!CLEAN/FUNED_AGOSTO-2018'

file_6 = '../DATA/!CLEAN/RIO_DE_JANEIRO'

file_7 = '../DATA/!CLEAN/YFV_LACEN_BAHIA'

# %%
file_list = [file_1,
            file_2,
            file_3,
            file_4,
            file_5,
            file_6,
            file_7]
seq_list = []
metadata_list = []

# %%
for file in file_list:
    seq_file = file + '.aln'
    metadata_file = file + '.xlsx'
    
    seq_list.append(seq_file)
    metadata_list.append(metadata_file)

# %% [markdown]
# ### Dataframes containing NHP YFV sequences
# A function to iterate over all file names and create a dataframe containing the **nucleotide sequences** for each one, putting them in a _dictionary_.

# %%
def create_seq_df(file):
    # Creates a dataframe based on a ".aln" file.
    
    # Gets the sequences IDs from a multi-fasta into a list
    identifiers = [seq_rec.id for seq_rec in SeqIO.parse(file, "clustal")]
    
    # Gets the sequences nucleotides, for each sequence in a multi-fasta
    seqs = np.array([list(str(seq_rec.seq)) for seq_rec in SeqIO.parse(file, "clustal")])
    
    # Creates columns names based on position, starting from 0.
    cols = list(range(seqs.shape[1]))
    
    # Creates dataframe with data
    seq_df = pd.DataFrame(seqs, index=identifiers, columns=cols)
    
    return seq_df

# %%
seq_dict = {}
for file in seq_list:
    print(file)
    df = create_seq_df(file)
    seq_dict[file] = df
# Out:
# ../DATA/!CLEAN/2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs.aln
# ../DATA/!CLEAN/NHP_65_outbreak.aln
# ../DATA/!CLEAN/2018-01_Salvador.aln
# ../DATA/!CLEAN/2018-03-04_LACEN_Bahia.aln
# ../DATA/!CLEAN/FUNED_AGOSTO-2018.aln
# ../DATA/!CLEAN/RIO_DE_JANEIRO.aln
# ../DATA/!CLEAN/YFV_LACEN_BAHIA.aln

# %%
sizes = [len(seq_dict[file]) for file in seq_list]
n_seqs = sum(sizes)
print(sizes)
print(n_seqs)
# Out:
# [32, 26, 16, 1, 12, 2, 9]
# 98

# %% [markdown]
# ### NHP Metadata
# The following code reads the excel spreadsheet containing the metadata related to the sequences and includes them in the dataframe.
#
# One spreadsheet per group of sequences from ZIBRA database, all into a _dictionary_.
#
# I only keep the information I'm going to use now, i.e., 'Host', 'Date' and 'Ct'.
#
# I use regex to link the spreadsheet to the sequences.

# %%
def read_metadata(excel_file):
    metadata_df = pd.read_excel(excel_file, index_col='index')
    metadata_df = metadata_df[['Host', 'Date', 'Ct']]
    return metadata_df

# %%
metadata_dict = {}
for file in metadata_list:
    print(file)
    metadata_df = read_metadata(file)
    metadata_dict[file] = metadata_df
# Out:
# ../DATA/!CLEAN/2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs.xlsx
# ../DATA/!CLEAN/NHP_65_outbreak.xlsx
# ../DATA/!CLEAN/2018-01_Salvador.xlsx
# ../DATA/!CLEAN/2018-03-04_LACEN_Bahia.xlsx
# ../DATA/!CLEAN/FUNED_AGOSTO-2018.xlsx
# ../DATA/!CLEAN/RIO_DE_JANEIRO.xlsx
# ../DATA/!CLEAN/YFV_LACEN_BAHIA.xlsx

# %%
sizes = [len(metadata_dict[file]) for file in metadata_list]
n_meta = sum(sizes)
print(sizes)
print(n_meta)
# Out:
# [60, 27, 21, 11, 15, 2, 22]
# 158

# %%
indexes = [metadata_dict[file].index for file in metadata_list]
sum([len(index) for index in indexes])
# Out:
# 158

# %% [markdown]
# # Regex - Merge information on metadata to dna sequence dataframe
# Parse through metadata and sequences IDs, linking information and adding it to the seqs dataframes.

# %%
import re

# %%
index_bookeeping = {} # to avoid matching multiple sequences for the same ID.
index_search = {}     #Just an auxiliary variable I used to see if all indexes were being counted.
count = 0

for file in file_list: # compare seq_df to metadata_df in a pairwise manner.
    seq_file = file + '.aln'
    metadata_file = file + '.xlsx'
    
    # Here I hold both the sequence df and the metadata df, to merge information.
    seq_df = seq_dict[seq_file]
    metadata_df = metadata_dict[metadata_file]
    
    # Prepare seq_df to receive the metadata info.
    seq_df.insert(0, 'ID', 'id')
    seq_df.insert(1, 'Host', 'host')
    seq_df.insert(2, 'Ct', 'ct')
    seq_df.insert(3, 'Date', 'date')
    
    # For each ID in metadata (here in its index).
    # In the excel files, there is a column called "index".
    # This column was used as the "metadata dataframe" index.
    # So I iterate over these indexes and look for them (try to match them using regex) in the fasta file ID.
    
    # for each index, and each metadata related to that index.
    for index_meta, meta in metadata_df.iterrows():
        
        #Just an auxiliary variable I used to see if all indexes were being counted.
        if index_meta not in index_search:
            index_search[index_meta] = 1
        else:
            index_search[index_meta] += 1
            
        # I have pre-edited the fasta files ID fields to put the index values between vertical bars "|".
        # This was to make it easier to create a pattern and use regex.
        pattern = '\|' + str(index_meta) + '\|'
        regex = re.compile(pattern)
        
        # For each fasta ID (index_seq) in the file...
        for index_b, sample_b in seq_df.iterrows():
            # If the metadata index is in this fasta ID...
            if regex.search(index_b):
                # if this sequence still has no metadata values associated...
                if seq_df.loc[index_b,'ID'] == 'id':
                    # fill in metadata values to seq_df
                    seq_df.loc[index_b,'ID'] = index_meta
                    seq_df.loc[index_b,'Host'] = metadata_df.loc[index_meta, 'Host']
                    seq_df.loc[index_b,'Date'] = metadata_df.loc[index_meta, 'Date']
                    seq_df.loc[index_b,'Ct'] = metadata_df.loc[index_meta, 'Ct']
                    index_bookeeping[index_meta] = 1
                # else, if this sequence already has metadata values associated
                # (this happens because identical sequences are grouped together, and their fasta IDs 
                # keep all the information of all these sequences)
                # and if this is the first time this specific index_meta is matched...
                elif index_meta not in index_bookeeping:
                    # Copy the sequence, but with new metadata, and append it to seq_df
                    sample_copy = pd.Series(sample_b)
                    index_copy = str(index_meta+'_')+str(index_b)
                    sample_copy.name = index_copy
                    seq_df.append(sample_copy)
                    seq_df.loc[index_copy,'ID'] = index_meta
                    seq_df.loc[index_copy,'Host'] = metadata_df.loc[index_meta, 'Host']
                    seq_df.loc[index_copy,'Date'] = metadata_df.loc[index_meta, 'Date']
                    seq_df.loc[index_copy,'Ct'] = metadata_df.loc[index_meta, 'Ct']
                    index_bookeeping[index_meta] = 1
                else:
                    index_bookeeping[index_meta] += 1

# %%
#index_search

# %%
#len(index_search)

# %% [markdown]
# Both the `index_search` and the `len(index_search)` results show that there are duplicate metadata in the spreadsheets. I manually checked it, and it is indeed duplicated, with the exact values (it is consistent).
#
# So there is no problem here.
#
# The difference between the number of metadata and sequences is due to identical sequences and some low quality sequences I manually removed.

# %% [markdown]
# ### Merge all dataframes into one

# %%
dfs = list(seq_dict.values())

# %%
len(dfs)
# Out:
# 7

# %%
for df in dfs:
    print(df.shape)
# Out:
# (32, 10084)
# (26, 10084)
# (16, 10084)
# (1, 10084)
# (12, 10084)
# (2, 10084)
# (9, 10084)

# %%
seq_df = pd.concat(dfs)

# %%
seq_df
# Out:
#                                                        ID            Host  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  RJY01        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  RJY03        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  RJY04        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  RJY05        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  RJY09        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY10|...  RJY10        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY12|...  RJY12        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY13|...  RJY13        Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY14|...  RJY14      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY15|...  RJY15      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY16|...  RJY16      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY18|...  RJY18      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY19|...  RJY19      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY22|...  RJY22      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY31|...  RJY31      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY32|...  RJY32      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY33|...  RJY33      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY34|...  RJY34      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY36|...  RJY36      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY37|...  RJY37      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY38|...  RJY38      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY39|...  RJY39      Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY40|...  RJY40      Callicebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY41|...  RJY41      Callicebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY43|...  RJY43      Callicebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY44|...  RJY44      Callicebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY46|...  RJY46           Cebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY47|...  RJY47           Cebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY48|...  RJY48           Cebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY49|...  RJY49           Cebus
# ...                                                   ...             ...
# 2018-01_Salvador|SA60|_BC11_YiBRAlibrary4_07022...   SA60        Allouata
# 2018-01_Salvador|SA46|_BC09_YiBRAlibrary3_01022...   SA46         Cebidae
# 2018-01_Salvador|SA48|_BC11_YiBRAlibrary3_01022...   SA48      Callithrix
# 2018-01_Salvador|SA3|_BC02_YiBRAlibrary1_300120...    SA3        Allouata
# 2018-01_Salvador|SA4|_BC03_YiBRAlibrary1_300120...    SA4        Allouata
# 2018-01_Salvador|SA6|_BC04_YiBRAlibrary1_300120...    SA6        Allouata
# 2018-03-04_LACEN_Bahia|SA48|_Callithrix_ct14_da...   SA48      Callithrix
# FUNED_AGOSTO-2018|FAH50662/|BC33|_FAH50662.prim...   BC33        Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC18|_FAH50662.prim...   BC18        Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC34|_FAH50662.prim...   BC34      Callithrix
# FUNED_AGOSTO-2018|FAH50662/|BC20|_FAH50662.prim...     id            host
# FUNED_AGOSTO-2018|FAH50662/|BC21|_FAH50662.prim...   BC21        Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...   BC22        Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...   BC23         cebidae
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...   BC24        Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...   BC27        Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...   BC30         cebidae
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...   BC31         cebidae
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...   BC32        Alouatta
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...   BC10      Callithrix
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...   BC11      Callithrix
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\       RJ258  Sem informação
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\     RJ259      Callithrix
# YFV_LACEN_BAHIA|RJ260|_YFV_SANTA_RITA_DE_CASSIA...  RJ260        Alouatta
# YFV_LACEN_BAHIA|RJ261|_YFV_CAMACARI_2017.03.16\     RJ261      Callithrix
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\     RJ267      Callithrix
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...  RJ268      Callithrix
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\    RJ272      Callithrix
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\         RJ274      Callithrix
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...  RJ292      Callithrix
#
#                                                         Ct  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...   11.22
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...   11.56
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...   11.45
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...   11.04
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...    22.3
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY10|...  14.335
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY12|...  16.425
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY13|...   14.43
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY14|...  20.715
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY15|...  13.395
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY16|...   27.22
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY18|...   26.09
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY19|...  12.545
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY22|...  18.065
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY31|...  10.805
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY32|...  11.065
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY33|...  10.875
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY34|...  10.865
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY36|...  11.075
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY37|...   11.07
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY38|...   5.685
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY39|...   11.66
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY40|...  12.585
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY41|...   10.46
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY43|...   11.99
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY44|...   10.48
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY46|...   15.36
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY47|...  11.385
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY48|...   10.65
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY49|...  15.625
# ...                                                    ...
# 2018-01_Salvador|SA60|_BC11_YiBRAlibrary4_07022...   14.15
# 2018-01_Salvador|SA46|_BC09_YiBRAlibrary3_01022...   10.77
# 2018-01_Salvador|SA48|_BC11_YiBRAlibrary3_01022...   13.85
# 2018-01_Salvador|SA3|_BC02_YiBRAlibrary1_300120...      11
# 2018-01_Salvador|SA4|_BC03_YiBRAlibrary1_300120...    9.19
# 2018-01_Salvador|SA6|_BC04_YiBRAlibrary1_300120...   7.535
# 2018-03-04_LACEN_Bahia|SA48|_Callithrix_ct14_da...   13.85
# FUNED_AGOSTO-2018|FAH50662/|BC33|_FAH50662.prim...   12.35
# FUNED_AGOSTO-2018|FAH50662/|BC18|_FAH50662.prim...    5.54
# FUNED_AGOSTO-2018|FAH50662/|BC34|_FAH50662.prim...   12.68
# FUNED_AGOSTO-2018|FAH50662/|BC20|_FAH50662.prim...      ct
# FUNED_AGOSTO-2018|FAH50662/|BC21|_FAH50662.prim...    7.46
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...    7.87
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...       8
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...    8.64
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...    8.78
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...   10.14
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...   11.36
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...   11.87
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...  21.765
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...   11.88
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\        25.81
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\      30.51
# YFV_LACEN_BAHIA|RJ260|_YFV_SANTA_RITA_DE_CASSIA...   27.43
# YFV_LACEN_BAHIA|RJ261|_YFV_CAMACARI_2017.03.16\      29.39
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\      29.18
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...   31.54
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\     34.58
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\          30.68
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...   30.87
#
#                                                                    Date  0  1  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  2017-03-08 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  2017-05-02 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  2017-12-22 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  2018-01-18 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  2017-02-13 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY10|...  2018-02-19 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY12|...  2017-02-15 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY13|...  2017-04-17 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY14|...  2017-06-06 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY15|...  2017-03-09 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY16|...  2017-03-02 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY18|...  2017-02-07 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY19|...  2017-02-16 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY22|...  2017-02-13 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY31|...  2018-02-28 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY32|...  2018-04-03 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY33|...  2018-04-03 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY34|...  2018-04-13 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY36|...  2018-04-12 00:00:00  N  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY37|...  2018-04-24 00:00:00  N  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY38|...  2018-07-17 00:00:00  N  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY39|...  2018-03-13 00:00:00  N  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY40|...  2018-04-09 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY41|...  2017-02-14 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY43|...  2017-01-31 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY44|...  2017-02-13 00:00:00  N  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY46|...  2017-02-09 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY47|...  2017-02-09 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY48|...  2017-01-31 00:00:00  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY49|...  2017-02-14 00:00:00  A  A
# ...                                                                 ... .. ..
# 2018-01_Salvador|SA60|_BC11_YiBRAlibrary4_07022...  2018-01-06 00:00:00  A  A
# 2018-01_Salvador|SA46|_BC09_YiBRAlibrary3_01022...  2017-12-26 00:00:00  A  A
# 2018-01_Salvador|SA48|_BC11_YiBRAlibrary3_01022...  2017-12-18 00:00:00  A  A
# 2018-01_Salvador|SA3|_BC02_YiBRAlibrary1_300120...           28.11.2017  A  A
# 2018-01_Salvador|SA4|_BC03_YiBRAlibrary1_300120...           15.12.2017  A  A
# 2018-01_Salvador|SA6|_BC04_YiBRAlibrary1_300120...           22.12.2017  A  A
# 2018-03-04_LACEN_Bahia|SA48|_Callithrix_ct14_da...  2017-12-18 00:00:00  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC33|_FAH50662.prim...  2017-12-04 00:00:00  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC18|_FAH50662.prim...  2017-03-24 00:00:00  N  N
# FUNED_AGOSTO-2018|FAH50662/|BC34|_FAH50662.prim...  2017-04-22 00:00:00  N  N
# FUNED_AGOSTO-2018|FAH50662/|BC20|_FAH50662.prim...                 date  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC21|_FAH50662.prim...  2017-05-05 00:00:00  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...  2017-04-06 00:00:00  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...  2017-04-12 00:00:00  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...  2017-04-03 00:00:00  N  N
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...  2017-03-13 00:00:00  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...  2017-11-09 00:00:00  A  A
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...  2017-03-14 00:00:00  N  N
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...  2017-01-16 00:00:00  A  A
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...  2018-09-19 00:00:00  A  A
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...  2018-09-19 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\       2018-02-15 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\     2018-02-15 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ260|_YFV_SANTA_RITA_DE_CASSIA...  2018-02-15 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ261|_YFV_CAMACARI_2017.03.16\     2018-02-15 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\     2018-02-15 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...  2018-02-15 00:00:00  N  N
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\    2018-02-15 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\         2018-02-16 00:00:00  A  A
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...  2018-02-16 00:00:00  A  A
#
#                                                     2  3  4  5  ... 10070  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY10|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY12|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY13|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY14|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY15|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY16|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY18|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY19|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY22|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY31|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY32|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY33|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY34|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY36|...  N  N  N  N  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY37|...  N  N  N  N  ...     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY38|...  N  N  N  N  ...     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY39|...  N  N  N  N  ...     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY40|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY41|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY43|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY44|...  N  N  N  N  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY46|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY47|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY48|...  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY49|...  A  A  C  C  ...     C
# ...                                                .. .. .. ..  ...   ...
# 2018-01_Salvador|SA60|_BC11_YiBRAlibrary4_07022...  A  A  C  C  ...     C
# 2018-01_Salvador|SA46|_BC09_YiBRAlibrary3_01022...  A  A  C  C  ...     C
# 2018-01_Salvador|SA48|_BC11_YiBRAlibrary3_01022...  A  A  C  C  ...     C
# 2018-01_Salvador|SA3|_BC02_YiBRAlibrary1_300120...  A  A  C  C  ...     C
# 2018-01_Salvador|SA4|_BC03_YiBRAlibrary1_300120...  A  A  C  C  ...     C
# 2018-01_Salvador|SA6|_BC04_YiBRAlibrary1_300120...  A  A  C  C  ...     C
# 2018-03-04_LACEN_Bahia|SA48|_Callithrix_ct14_da...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC33|_FAH50662.prim...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC18|_FAH50662.prim...  N  N  N  N  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC34|_FAH50662.prim...  N  N  N  N  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC20|_FAH50662.prim...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC21|_FAH50662.prim...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...  N  N  N  N  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...  A  A  C  C  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...  N  N  N  N  ...     C
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...  A  A  C  C  ...     C
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...  A  A  C  C  ...     C
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...  A  A  C  C  ...     C
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\       A  A  C  C  ...     C
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\     A  A  C  C  ...     C
# YFV_LACEN_BAHIA|RJ260|_YFV_SANTA_RITA_DE_CASSIA...  A  A  C  C  ...     C
# YFV_LACEN_BAHIA|RJ261|_YFV_CAMACARI_2017.03.16\     A  A  C  C  ...     C
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\     A  A  C  C  ...     N
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...  N  N  N  N  ...     N
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\    A  A  C  C  ...     C
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\         A  A  C  C  ...     C
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...  A  A  C  C  ...     C
#
#                                                    10071 10072 10073 10074  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY10|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY12|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY13|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY14|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY15|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY16|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY18|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY19|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY22|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY31|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY32|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY33|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY34|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY36|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY37|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY38|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY39|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY40|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY41|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY43|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY44|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY46|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY47|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY48|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY49|...     A     G     A     G
# ...                                                  ...   ...   ...   ...
# 2018-01_Salvador|SA60|_BC11_YiBRAlibrary4_07022...     A     G     A     G
# 2018-01_Salvador|SA46|_BC09_YiBRAlibrary3_01022...     A     G     A     G
# 2018-01_Salvador|SA48|_BC11_YiBRAlibrary3_01022...     A     G     A     G
# 2018-01_Salvador|SA3|_BC02_YiBRAlibrary1_300120...     A     G     A     G
# 2018-01_Salvador|SA4|_BC03_YiBRAlibrary1_300120...     A     G     A     G
# 2018-01_Salvador|SA6|_BC04_YiBRAlibrary1_300120...     A     G     A     G
# 2018-03-04_LACEN_Bahia|SA48|_Callithrix_ct14_da...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC33|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC18|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC34|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC20|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC21|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...     A     G     A     G
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...     A     G     A     G
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...     A     G     A     G
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...     A     G     A     G
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\          A     G     A     G
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\        A     G     A     G
# YFV_LACEN_BAHIA|RJ260|_YFV_SANTA_RITA_DE_CASSIA...     A     G     A     G
# YFV_LACEN_BAHIA|RJ261|_YFV_CAMACARI_2017.03.16\        A     G     A     G
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\        N     N     N     N
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...     N     N     N     N
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\       A     G     A     G
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\            A     G     A     G
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...     A     G     A     G
#
#                                                    10075 10076 10077 10078  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY10|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY12|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY13|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY14|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY15|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY16|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY18|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY19|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY22|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY31|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY32|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY33|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY34|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY36|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY37|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY38|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY39|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY40|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY41|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY43|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY44|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY46|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY47|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY48|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY49|...     C     C     A     C
# ...                                                  ...   ...   ...   ...
# 2018-01_Salvador|SA60|_BC11_YiBRAlibrary4_07022...     C     C     A     C
# 2018-01_Salvador|SA46|_BC09_YiBRAlibrary3_01022...     C     C     A     C
# 2018-01_Salvador|SA48|_BC11_YiBRAlibrary3_01022...     C     C     A     C
# 2018-01_Salvador|SA3|_BC02_YiBRAlibrary1_300120...     C     C     A     C
# 2018-01_Salvador|SA4|_BC03_YiBRAlibrary1_300120...     C     C     A     C
# 2018-01_Salvador|SA6|_BC04_YiBRAlibrary1_300120...     C     C     A     C
# 2018-03-04_LACEN_Bahia|SA48|_Callithrix_ct14_da...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC33|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC18|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC34|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC20|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC21|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...     C     C     A     C
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...     C     C     A     C
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...     C     C     A     C
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...     C     C     A     C
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\          C     C     A     C
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\        C     C     A     C
# YFV_LACEN_BAHIA|RJ260|_YFV_SANTA_RITA_DE_CASSIA...     C     C     A     C
# YFV_LACEN_BAHIA|RJ261|_YFV_CAMACARI_2017.03.16\        C     C     A     C
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\        N     N     N     N
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...     N     N     N     N
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\       C     C     A     C
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\            C     C     A     C
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...     C     C     A     C
#
#                                                    10079
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY10|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY12|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY13|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY14|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY15|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY16|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY18|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY19|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY22|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY31|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY32|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY33|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY34|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY36|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY37|...     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY38|...     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY39|...     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY40|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY41|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY43|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY44|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY46|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY47|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY48|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY49|...     T
# ...                                                  ...
# 2018-01_Salvador|SA60|_BC11_YiBRAlibrary4_07022...     T
# 2018-01_Salvador|SA46|_BC09_YiBRAlibrary3_01022...     T
# 2018-01_Salvador|SA48|_BC11_YiBRAlibrary3_01022...     T
# 2018-01_Salvador|SA3|_BC02_YiBRAlibrary1_300120...     T
# 2018-01_Salvador|SA4|_BC03_YiBRAlibrary1_300120...     T
# 2018-01_Salvador|SA6|_BC04_YiBRAlibrary1_300120...     T
# 2018-03-04_LACEN_Bahia|SA48|_Callithrix_ct14_da...     T
# FUNED_AGOSTO-2018|FAH50662/|BC33|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC18|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC34|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC20|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC21|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...     T
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...     T
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...     T
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...     T
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\          T
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\        T
# YFV_LACEN_BAHIA|RJ260|_YFV_SANTA_RITA_DE_CASSIA...     T
# YFV_LACEN_BAHIA|RJ261|_YFV_CAMACARI_2017.03.16\        T
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\        N
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...     N
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\       C
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\            T
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...     T
#
# [98 rows x 10084 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Clear missing values
#
# - First, turn all "N" and "-" into `np.nan`. This will mark the missing values.

# %%
seq_df.replace('N', np.nan, inplace=True)
seq_df.replace('-', np.nan, inplace=True)

# %% [markdown]
# - Second, keep only rows (samples) containing less then 5% missing values (NaN).

# %%
threshold = int(seq_df.shape[1]*0.95)

# %%
seq_df.dropna(axis=0, how='any', thresh=threshold, inplace=True)

# %%
seq_df.shape
# Out:
# (77, 10084)

# %% [markdown]
# - Third, remove all columns that still containg missing values.

# %%
seq_df.dropna(axis=1, how='any', inplace=True)

# %%
seq_df.shape
# Out:
# (77, 6550)

# %%
# Remove rows containing NaN or empty values in the Ct column
seq_df = seq_df[seq_df['Ct'].notnull()]
seq_df = seq_df[seq_df['Ct'] != 'ct']

# Make sure values in Ct column are float numeric
seq_df['Ct'] = pd.to_numeric(seq_df['Ct'])
seq_df['Ct'] = seq_df['Ct'].astype(np.float16)

# Make sure values in Date are datetime
seq_df['Date'] = pd.to_datetime(seq_df['Date'])

# Correct some values
seq_df.replace('Allouata', 'Alouatta', inplace=True)
seq_df.replace('cebidae', 'Cebidae', inplace=True)
seq_df.replace('NHP (unk)', 'unk', inplace=True)
seq_df.replace('Sem informação','unk', inplace=True)
seq_df.replace('Leontopithecus rosalia','L. rosalia', inplace=True)

# Show all hosts present
print(seq_df['Host'].unique())
# Out:
# ['Alouatta' 'Callithrix' 'Callicebus' 'Cebus' 'unk' 'Cebidae']

# %%
seq_df.head()
# Out:
#                                                        ID      Host  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  RJY01  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  RJY03  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  RJY04  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  RJY05  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  RJY09  Alouatta
#
#                                                            Ct       Date  0  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  11.218750 2017-03-08  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  11.562500 2017-05-02  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  11.453125 2017-12-22  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  11.039062 2018-01-18  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  22.296875 2017-02-13  A
#
#                                                     1  2  3  4  5  ... 10070  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  A  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  A  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  A  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  A  A  A  C  C  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  A  A  A  C  C  ...     C
#
#                                                    10071 10072 10073 10074  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     A     G     A     G
#
#                                                    10075 10076 10077 10078  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     C     C     A     C
#
#                                                    10079
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     T
#
# [5 rows x 10084 columns]

# %% [markdown]
# ## Seasons
# Prepare data to perform "epidemic season" analysis

# %%
# Insert another column on the dataset to hold the epidemiologic season
# 2016/2017
# 2017/2018
seq_df.insert(4, 'Season', 'season')

# %%
# Fill season values based on date condition:
# season 1: before August 2017
# season 2: after August 2017
mask = seq_df['Date'] < pd.datetime(2017,8,1)
seq_df.loc[mask, 'Season'] = '2016/2017'

mask = seq_df['Date'] >= pd.datetime(2017,8,1)
seq_df.loc[mask, 'Season'] = '2017/2018'

seq_df.head()
# Out:
#                                                        ID      Host  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  RJY01  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  RJY03  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  RJY04  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  RJY05  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  RJY09  Alouatta
#
#                                                            Ct       Date  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  11.218750 2017-03-08
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  11.562500 2017-05-02
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  11.453125 2017-12-22
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  11.039062 2018-01-18
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  22.296875 2017-02-13
#
#                                                        Season  0  1  2  3  4  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  2016/2017  A  A  A  A  C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  2016/2017  A  A  A  A  C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  2017/2018  A  A  A  A  C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  2017/2018  A  A  A  A  C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  2016/2017  A  A  A  A  C
#
#                                                     ... 10070 10071 10072  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  ...     C     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  ...     C     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  ...     C     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  ...     C     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  ...     C     A     G
#
#                                                    10073 10074 10075 10076  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     A     G     C     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     A     G     C     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     A     G     C     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     A     G     C     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     A     G     C     C
#
#                                                    10077 10078 10079
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     A     C     T
#
# [5 rows x 10085 columns]

# %% [markdown]
# ## High/Low Ct
# Prepare data to perform "high/low Ct" analysis

# %%
# Insert another column on the dataset to hold the Ct group
# high = 1
# low = 0
seq_df.insert(5, 'Ct_Group', 0)

# %%
Ct_threshold = 20

# %%
# Fill Ct groups based on:
# high: Ct > 20
# low: Ct <= 20
mask = seq_df['Ct'] <= Ct_threshold
seq_df.loc[mask, 'Ct_Group'] = 0

mask = seq_df['Ct'] > Ct_threshold
seq_df.loc[mask, 'Ct_Group'] = 1

seq_df.head()
# Out:
#                                                        ID      Host  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  RJY01  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  RJY03  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  RJY04  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  RJY05  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  RJY09  Alouatta
#
#                                                            Ct       Date  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  11.218750 2017-03-08
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  11.562500 2017-05-02
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  11.453125 2017-12-22
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  11.039062 2018-01-18
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  22.296875 2017-02-13
#
#                                                        Season  Ct_Group  0  1  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  2016/2017         0  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  2016/2017         0  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  2017/2018         0  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  2017/2018         0  A  A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  2016/2017         1  A  A
#
#                                                     2  3  ... 10070 10071  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  A  A  ...     C     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  A  A  ...     C     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  A  A  ...     C     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  A  A  ...     C     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  A  A  ...     C     A
#
#                                                    10072 10073 10074 10075  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     G     A     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     G     A     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     G     A     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     G     A     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     G     A     G     C
#
#                                                    10076 10077 10078 10079
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     C     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     C     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     C     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     C     A     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     C     A     C     T
#
# [5 rows x 10086 columns]

# %%
seq_df.groupby('Host')["ID"].count()
# Out:
# Host
# Alouatta      26
# Callicebus     4
# Callithrix    27
# Cebidae        8
# Cebus          5
# unk            6
# Name: ID, dtype: int64

# %% [markdown]
# ### We are left with a dataset containing 26 Alouatta samples and 27 Callithrix samples.
# - of the Callithrix samples, 6 are high Ct $(> 20)$ and 21 are low Ct $(< 20)$

# %%
for host, host_data in seq_df.groupby('Host'):
    print(host)
    print(host_data.groupby('Ct_Group')['ID'].count(), '\n')
    #print(b)
# Out:
# Alouatta
# Ct_Group
# 0    24
# 1     2
# Name: ID, dtype: int64
#
# Callicebus
# Ct_Group
# 0    4
# Name: ID, dtype: int64
#
# Callithrix
# Ct_Group
# 0    21
# 1     6
# Name: ID, dtype: int64
#
# Cebidae
# Ct_Group
# 0    8
# Name: ID, dtype: int64
#
# Cebus
# Ct_Group
# 0    5
# Name: ID, dtype: int64
#
# unk
# Ct_Group
# 0    5
# 1    1
# Name: ID, dtype: int64

# %% [markdown]
# # One hot encoding

# %%
nucleotides_df = seq_df.iloc[:, 6:]

# %%
nucleotides_df.head()
# Out:
#                                                    0     1     2     3      \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     A     A     A     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     A     A     A     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     A     A     A     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     A     A     A     A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     A     A     A     A
#
#                                                    4     5     6     7      \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     C     C     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     C     C     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     C     C     C   NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     C     C     C     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     C     C     C     T
#
#                                                    8     9      ... 10070  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     G     G  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     G     G  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...   NaN     G  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     G     G  ...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     G     G  ...     C
#
#                                                    10071 10072 10073 10074  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     A     G     A     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     A     G     A     G
#
#                                                    10075 10076 10077 10078  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     C     C     A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     C     C     A     C
#
#                                                    10079
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...     T
#
# [5 rows x 10080 columns]

# %%
seq_ohe_df = pd.get_dummies(nucleotides_df)
seq_ohe_df.head()
# Out:
#                                                     0_A  1_A  2_A  3_A  4_C  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...    1    1    1    1    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...    1    1    1    1    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...    1    1    1    1    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...    1    1    1    1    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...    1    1    1    1    1
#
#                                                     5_C  6_C  7_T  8_G  9_G  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...    1    1    1    1    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...    1    1    1    1    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...    1    1    0    0    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...    1    1    1    1    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...    1    1    1    1    1
#
#                                                     ...  10070_C  10071_A  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  ...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  ...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  ...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  ...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  ...        1        1
#
#                                                     10072_G  10073_A  10074_G  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...        1        1        1
#
#                                                     10075_C  10076_C  10077_A  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...        1        1        1
#
#                                                     10078_C  10079_T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...        1        1
#
# [5 rows x 10404 columns]

# %%
seq_ohe_df.shape
# Out:
# (76, 10404)

# %%
seq_df.shape
# Out:
# (76, 10086)

# %%
seq_ohe_df.index == seq_df.index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
seq_ohe_df.insert(0, 'ID', seq_df['ID'])
seq_ohe_df.insert(1, 'Host', seq_df['Host'])
seq_ohe_df.insert(2, 'Ct', seq_df['Ct'])
seq_ohe_df.insert(3, 'Date', seq_df['Date'])
seq_ohe_df.insert(4, 'Season', seq_df['Season'])
seq_ohe_df.insert(5, 'Ct_Group', seq_df['Ct_Group'])

# %%
seq_ohe_df.head()
# Out:
#                                                        ID      Host  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  RJY01  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  RJY03  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  RJY04  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  RJY05  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  RJY09  Alouatta
#
#                                                            Ct       Date  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  11.218750 2017-03-08
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  11.562500 2017-05-02
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  11.453125 2017-12-22
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  11.039062 2018-01-18
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  22.296875 2017-02-13
#
#                                                        Season  Ct_Group  0_A  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...  2016/2017         0    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...  2016/2017         0    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...  2017/2018         0    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...  2017/2018         0    1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...  2016/2017         1    1
#
#                                                     1_A  2_A  3_A  ...  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...    1    1    1  ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...    1    1    1  ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...    1    1    1  ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...    1    1    1  ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...    1    1    1  ...
#
#                                                     10070_C  10071_A  10072_G  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...        1        1        1
#
#                                                     10073_A  10074_G  10075_C  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...        1        1        1
#
#                                                     10076_C  10077_A  10078_C  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...        1        1        1
#
#                                                     10079_T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY01|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY03|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY04|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY05|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_Cts|RJY09|...        1
#
# [5 rows x 10410 columns]

# %% [markdown]
# # Save to .csv and .pkl

# %%
seq_ohe_df.to_csv('../DATA/!CLEAN/YFV_seq_ohe_df.csv', index=True, header=True, decimal='.', sep=',', float_format='%.2f')

# %%
seq_ohe_df.to_pickle('../DATA/!CLEAN/YFV_seq_ohe_df.pkl')

# %%
seq_df.to_pickle('../DATA/!CLEAN/YFV_seq_df.pkl')
