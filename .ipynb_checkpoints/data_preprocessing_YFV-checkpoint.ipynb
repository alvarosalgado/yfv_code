# %%
# %matplotlib inline

from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.ensemble import RandomForestClassifier

import shap

# %%
shap.__version__
# Out:
# '0.28.5'

# %% [markdown]
# ### Sequence alignment files (.aln format)

# %% [markdown]
# Put the files names (relative paths) in a list.
#
# We will iterate over this list to read the sequences into dataframes.

# %%
file_1 = '../DATA/!CLEAN/2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs'

file_2 = '../DATA/!CLEAN/NHP_65_outbreak'

file_3 = '../DATA/!CLEAN/2018-01_Salvador'

file_4 = '../DATA/!CLEAN/2018-03-04_LACEN_Bahia'

file_5 = '../DATA/!CLEAN/FUNED_AGOSTO-2018'

file_6 = '../DATA/!CLEAN/RIO_DE_JANEIRO'

file_7 = '../DATA/!CLEAN/YFV_LACEN_BAHIA'

# %%
file_list = [file_1,
            file_2,
            file_3,
            file_4,
            file_5,
            file_6,
            file_7]
seq_list = []
metadata_list = []

# %%
for file in file_list:
    seq_file = file + '.aln'
    metadata_file = file + '.xlsx'
    
    seq_list.append(seq_file)
    metadata_list.append(metadata_file)

# %% [markdown]
# ### Dataframes containing YFV sequences
# A function to iterate over all file names and create a dataframe containing the **nucleotide sequences** for each one, putting them in a _dictionary_.

# %%
def create_seq_df(file):
    # Creates a dataframe based on a ".aln" file.
    
    # Gets the sequences IDs
    identifiers = [seq_record.id for seq_record in SeqIO.parse(file, "clustal")]
    
    # Gets the sequences nucleotides
    seq = np.array([list(str(seq_rec.seq)) for seq_rec in SeqIO.parse(file, "clustal")])
    
    # Creates columns names based on position, starting from 1, to make it consistent with the 
    # sequence analysis, which starts at base number 1.
    cols = list(range(1, seq.shape[1]+1))
    
    # Creates dataframe with data
    seq_df = pd.DataFrame(seq, index=identifiers, columns=cols)
    
    return seq_df

# %%
seq_dict = {}
for file in seq_list:
    print(file)
    df = create_seq_df(file)
    seq_dict[file] = df
# Out:
# ../DATA/!CLEAN/2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs.aln
# ../DATA/!CLEAN/NHP_65_outbreak.aln
# ../DATA/!CLEAN/2018-01_Salvador.aln
# ../DATA/!CLEAN/2018-03-04_LACEN_Bahia.aln
# ../DATA/!CLEAN/FUNED_AGOSTO-2018.aln
# ../DATA/!CLEAN/RIO_DE_JANEIRO.aln
# ../DATA/!CLEAN/YFV_LACEN_BAHIA.aln

# %% [markdown]
# ### Metadata
# The following code reads the excel spreadsheet containing the metadata related to the sequences and includes them in the dataframe.
#
# One spreadsheet per group of sequences from ZIBRA database, all into a _dictionary_.
#
# I only keep the information I'm going to use now, i.e., 'Host', 'Date' and 'Ct'.
#
# I use regex to link the spreadsheet to the sequences.

# %%
def read_metadata(excel_file):
    metadata_df = pd.read_excel(excel_file, index_col='index')
    metadata_df = metadata_df[['Host', 'Date', 'Ct']]
    return metadata_df

# %%
metadata_dict = {}
for file in metadata_list:
    print(file)
    metadata_df = read_metadata(file)
    metadata_dict[file] = metadata_df
# Out:
# ../DATA/!CLEAN/2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs.xlsx
# ../DATA/!CLEAN/NHP_65_outbreak.xlsx
# ../DATA/!CLEAN/2018-01_Salvador.xlsx
# ../DATA/!CLEAN/2018-03-04_LACEN_Bahia.xlsx
# ../DATA/!CLEAN/FUNED_AGOSTO-2018.xlsx
# ../DATA/!CLEAN/RIO_DE_JANEIRO.xlsx
# ../DATA/!CLEAN/YFV_LACEN_BAHIA.xlsx

# %% [markdown]
# ### Regex
# Parse through metadata and sequences IDs, linking information and adding it to the seqs dataframes.

# %%
import re

# %%
index_bookeeping = {} # to avoid matching multiple sequences for the same ID.
for file in file_list: # compare seq_df to metadata_df in a pairwise manner.
    seq_file = file + '.aln'
    metadata_file = file + '.xlsx'
    
    seq_df = seq_dict[seq_file]
    metadata_df = metadata_dict[metadata_file]
    
    # Prepare seq_df to receive the metadata info.
    seq_df.insert(0, 'ID', 'id')
    seq_df.insert(1, 'Host', 'host')
    seq_df.insert(2, 'Ct', 'ct')
    seq_df.insert(3, 'Date', 'date')
    
    # For each ID in metadata (here in its index).
    # In the excel files, there is a column called "index".
    # This column was used as the "metadata dataframe" index.
    # So I iterate over these indexes and look for them (try to match them using regex) in the fasta file ID.
    for index_a, sample_a in metadata_df.iterrows():
        # I have pre-edited the fasta files ID fields to put the index values between vertical bars "|".
        # This was to make it easier to create a pattern and use regex.
        pattern = '\|' + str(index_a) + '\|'
        regex = re.compile(pattern)
        # For each fasta ID (index_b) in the file...
        for index_b, sample_b in seq_df.iterrows():
            # If the metadata index is in this fasta ID...
            if regex.search(index_b):
                # if this sequence still has no metadata values associated...
                if seq_df.loc[index_b,'ID'] == 'id':
                    # fill in metadata values to seq_df
                    seq_df.loc[index_b,'ID'] = index_a
                    seq_df.loc[index_b,'Host'] = metadata_df.loc[index_a, 'Host']
                    seq_df.loc[index_b,'Date'] = metadata_df.loc[index_a, 'Date']
                    seq_df.loc[index_b,'Ct'] = metadata_df.loc[index_a, 'Ct']
                    index_bookeeping[index_a] = 1
                # else, if this sequence already has metadata values associated
                # (this happens because identical sequences are grouped together, and their fasta IDs 
                # keep all the information of all these sequences)
                # and if this is the first time this specific index_a is matched...
                elif index_a not in index_bookeeping:
                    # Copy the sequence, but with new metadata, and append it to seq_df
                    sample_copy = pd.Series(sample_b)
                    index_copy = str(index_a+'_')+str(index_b)
                    sample_copy.name = index_copy
                    seq_df.append(sample_copy)
                    seq_df.loc[index_copy,'ID'] = index_a
                    seq_df.loc[index_copy,'Host'] = metadata_df.loc[index_a, 'Host']
                    seq_df.loc[index_copy,'Date'] = metadata_df.loc[index_a, 'Date']
                    seq_df.loc[index_copy,'Ct'] = metadata_df.loc[index_a, 'Ct']
                    index_bookeeping[index_a] = 1

# %% [markdown]
# ### Merge all dataframes into one

# %%
dfs = list(seq_dict.values())

# %%
seq_df = pd.concat(dfs)

# %% [markdown]
# ### Data Cleaning

# %%
seq_df = seq_df[seq_df['Ct'].notnull()]

seq_df = seq_df[seq_df['Ct'] != 'ct']

seq_df['Ct'] = pd.to_numeric(seq_df['Ct'])

seq_df['Ct'] = seq_df['Ct'].astype(np.float16)

seq_df['Date'] = pd.to_datetime(seq_df['Date'])

seq_df.replace('Allouata', 'Alouatta', inplace=True)
seq_df.replace('cebidae', 'Cebidae', inplace=True)
seq_df.replace('NHP (unk)', 'unk', inplace=True)
seq_df.replace('Sem informação','unk', inplace=True)

print(seq_df['Host'].unique())
# Out:
# ['Alouatta' 'Callithrix' 'Callicebus' 'Cebus' 'unk' 'Cebidae']

# %%
seq_df.head()
# Out:
#                                                        ID      Host  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...  RJY01  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...  RJY03  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...  RJY04  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...  RJY05  Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...  RJY09  Alouatta
#
#                                                            Ct       Date  1  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...  11.218750 2017-03-08  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...  11.562500 2017-05-02  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...  11.453125 2017-12-22  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...  11.039062 2018-01-18  N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...  22.296875 2017-02-13  N
#
#                                                     2  3  4  5  6  ...  10131  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...  N  N  N  N  N  ...      A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...  N  N  N  N  N  ...      A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...  N  N  N  N  N  ...      A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...  N  N  N  N  N  ...      A
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...  N  N  N  N  N  ...      A
#
#                                                    10132 10133 10134 10135  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...     C     A     N     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...     C     A     N     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...     C     A     N     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...     C     A     N     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...     C     A     N     C
#
#                                                    10136 10137 10138 10139  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...     G     C     A     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...     G     C     A     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...     G     C     A     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...     G     C     A     T
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...     G     C     A     T
#
#                                                    10140
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...     C
#
# [5 rows x 10144 columns]

# %%
seq_df.insert(4, 'Season', 'season')

# %%
mask = seq_df['Date'] < pd.datetime(2017,8,1)
seq_df.loc[mask, 'Season'] = '2016/2017'

mask = seq_df['Date'] >= pd.datetime(2017,8,1)
seq_df.loc[mask, 'Season'] = '2017/2018'

seq_df
# Out:
#                                                        ID        Host  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...  RJY01    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...  RJY03    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...  RJY04    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...  RJY05    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...  RJY09    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY10|...  RJY10    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY11|...  RJY11    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY12|...  RJY12    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY13|...  RJY13    Alouatta
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY14|...  RJY14  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY15|...  RJY15  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY16|...  RJY16  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY18|...  RJY18  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY19|...  RJY19  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY20|...  RJY20  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY21|...  RJY21  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY22|...  RJY22  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY30|...  RJY30  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY31|...  RJY31  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY32|...  RJY32  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY33|...  RJY33  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY34|...  RJY34  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY35|...  RJY35  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY36|...  RJY36  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY37|...  RJY37  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY38|...  RJY38  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY39|...  RJY39  Callithrix
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY40|...  RJY40  Callicebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY41|...  RJY41  Callicebus
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY43|...  RJY43  Callicebus
# ...                                                   ...         ...
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...   BC22    Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...   BC23     Cebidae
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...   BC24    Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC26|_FAH50662.prim...   BC26  Callithrix
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...   BC27    Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC28|_FAH50662.prim...   BC28    Alouatta
# FUNED_AGOSTO-2018|FAH50662/|BC29|_FAH50662.prim...   BC29       Cebus
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...   BC30     Cebidae
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...   BC31     Cebidae
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...   BC32    Alouatta
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...   BC10  Callithrix
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...   BC11  Callithrix
# YFV_LACEN_BAHIA|RJ250|_YFV_SAO_MIGUEL_DAS_MATAS...  RJ250  Callithrix
# YFV_LACEN_BAHIA|RJ251|_YFV_CORDEIROS_2017.03.10\    RJ251  Callithrix
# YFV_LACEN_BAHIA|RJ252|_YFV_SAO_FELIPE_2017.03.10\   RJ252  Callithrix
# YFV_LACEN_BAHIA|RJ253|_YFV_SALVADOR_2017.03.14\     RJ253  Callithrix
# YFV_LACEN_BAHIA|RJ256|_YFV_ALAGOINHAS_2017.03.14\   RJ256  Callithrix
# YFV_LACEN_BAHIA|RJ257|_YFV_CATU_2017.03.15\         RJ257  Callithrix
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\       ...      A     C     A
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\...  ...      A     C     A
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\     ...      N     N     N
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...  ...      N     N     N
# YFV_LACEN_BAHIA|RJ271|_ESPLANADA_2017.03.21\        ...      A     C     A
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\    ...      A     C     A
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\         ...      A     C     A
# YFV_LACEN_BAHIA|RJ276|_YFV_PAULO_AFONSO_2017.04...  ...      N     N     N
# YFV_LACEN_BAHIA|RJ277|_YFV_SALVADOR_2017.04.06\     ...      N     N     N
# YFV_LACEN_BAHIA|RJ278|_YFV_CANDEIAS_2017.04.06\     ...      N     N     N
# YFV_LACEN_BAHIA|RJ288|_YFV_RIACHAO_DO_JACUIPE_2...  ...      N     N     N
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...  ...      A     C     A
#
#                                                    10134 10135 10136 10137  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY10|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY11|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY12|...     C     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY13|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY14|...     C     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY15|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY16|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY18|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY19|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY20|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY21|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY22|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY30|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY31|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY32|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY33|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY34|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY35|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY36|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY37|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY38|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY39|...     N     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY40|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY41|...     N     C     G     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY43|...     C     C     G     C
# ...                                                  ...   ...   ...   ...
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC26|_FAH50662.prim...     N     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC28|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC29|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...     C     C     G     C
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...     C     C     G     C
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...     C     C     G     C
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...     C     C     G     C
# YFV_LACEN_BAHIA|RJ250|_YFV_SAO_MIGUEL_DAS_MATAS...     N     N     N     N
# YFV_LACEN_BAHIA|RJ251|_YFV_CORDEIROS_2017.03.10\       N     N     N     N
# YFV_LACEN_BAHIA|RJ252|_YFV_SAO_FELIPE_2017.03.10\      N     N     N     N
# YFV_LACEN_BAHIA|RJ253|_YFV_SALVADOR_2017.03.14\        N     N     N     N
# YFV_LACEN_BAHIA|RJ256|_YFV_ALAGOINHAS_2017.03.14\      N     N     N     N
# YFV_LACEN_BAHIA|RJ257|_YFV_CATU_2017.03.15\            N     N     N     N
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\          C     C     G     C
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\...     T     C     G     C
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\        N     N     N     N
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...     N     N     N     N
# YFV_LACEN_BAHIA|RJ271|_ESPLANADA_2017.03.21\           C     C     G     C
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\       C     C     G     C
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\            C     C     G     C
# YFV_LACEN_BAHIA|RJ276|_YFV_PAULO_AFONSO_2017.04...     N     N     N     N
# YFV_LACEN_BAHIA|RJ277|_YFV_SALVADOR_2017.04.06\        N     N     N     N
# YFV_LACEN_BAHIA|RJ278|_YFV_CANDEIAS_2017.04.06\        N     N     N     N
# YFV_LACEN_BAHIA|RJ288|_YFV_RIACHAO_DO_JACUIPE_2...     N     N     N     N
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...     C     C     G     C
#
#                                                    10138 10139 10140
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY10|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY11|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY12|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY13|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY14|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY15|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY16|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY18|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY19|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY20|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY21|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY22|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY30|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY31|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY32|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY33|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY34|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY35|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY36|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY37|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY38|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY39|...     N     N     N
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY40|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY41|...     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY43|...     A     T     C
# ...                                                  ...   ...   ...
# FUNED_AGOSTO-2018|FAH50662/|BC22|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC23|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC24|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC26|_FAH50662.prim...     A     T     N
# FUNED_AGOSTO-2018|FAH50662/|BC27|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC28|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC29|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC30|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC31|_FAH50662.prim...     A     T     C
# FUNED_AGOSTO-2018|FAH50662/|BC32|_FAH50662.prim...     A     T     C
# RIO_DE_JANEIRO|BC10|_CHIKV_RJ_library1_20180921...     A     T     C
# RIO_DE_JANEIRO|BC11|_CHIKV_RJ_library1_20180921...     A     T     C
# YFV_LACEN_BAHIA|RJ250|_YFV_SAO_MIGUEL_DAS_MATAS...     N     N     N
# YFV_LACEN_BAHIA|RJ251|_YFV_CORDEIROS_2017.03.10\       N     N     N
# YFV_LACEN_BAHIA|RJ252|_YFV_SAO_FELIPE_2017.03.10\      N     N     N
# YFV_LACEN_BAHIA|RJ253|_YFV_SALVADOR_2017.03.14\        N     N     N
# YFV_LACEN_BAHIA|RJ256|_YFV_ALAGOINHAS_2017.03.14\      N     N     N
# YFV_LACEN_BAHIA|RJ257|_YFV_CATU_2017.03.15\            N     N     N
# YFV_LACEN_BAHIA|RJ258|_YFV_PEDRAO_2017.03.15\          A     T     C
# YFV_LACEN_BAHIA|RJ259|_YFV_SALVADOR_2017.03.15\...     A     T     C
# YFV_LACEN_BAHIA|RJ267|_YFV_SALVADOR_2018.03.19\        N     N     N
# YFV_LACEN_BAHIA|RJ268|_YFV_FEIRA_DE_SANTANA_201...     N     N     N
# YFV_LACEN_BAHIA|RJ271|_ESPLANADA_2017.03.21\           A     T     C
# YFV_LACEN_BAHIA|RJ272|_YFV_BIRITINGA_2017.03.22\       A     T     C
# YFV_LACEN_BAHIA|RJ274|_YFV_ICHU_2017.04.05\            A     T     C
# YFV_LACEN_BAHIA|RJ276|_YFV_PAULO_AFONSO_2017.04...     N     N     N
# YFV_LACEN_BAHIA|RJ277|_YFV_SALVADOR_2017.04.06\        N     N     N
# YFV_LACEN_BAHIA|RJ278|_YFV_CANDEIAS_2017.04.06\        N     N     N
# YFV_LACEN_BAHIA|RJ288|_YFV_RIACHAO_DO_JACUIPE_2...     N     N     N
# YFV_LACEN_BAHIA|RJ292|_YFV_FEIRA_DE_SANTANA_201...     A     T     C
#
# [121 rows x 10145 columns]

# %%
import seaborn as sns
sns.set(style="whitegrid")

# %%
callithrix_df = seq_df[seq_df['Host'] == 'Callithrix']

alouatta_df = seq_df[seq_df['Host'] == 'Alouatta']

# %%
def plot_figures(filename, df):
    fig, ax = plt.subplots()

    x = df['Date'].values
    y = df['Ct'].values

    ax = plt.scatter(x, y);
    
    fig.savefig('Scatter_' + filename, format='png', dpi=300, transparent=False)
    
    fig, ax = plt.subplots()
    data_17 = df[df['Date'] <= pd.datetime(2017,8,1)]
    data_18 = df[df['Date'] > pd.datetime(2017,8,1)]
    ax = plt.boxplot([data_17['Ct'], data_18['Ct']], labels=['2016/2017', '2017/2018']);
    
    fig.savefig('BoxPlot_' + filename, format='png', dpi=300, transparent=False)
    
    fig, ax = plt.subplots()
    ax = sns.violinplot(x="Season", y="Ct", data=df)
    
    fig.savefig('ViolinPlot_' + filename, format='png', dpi=300, transparent=False)

# %%
plot_figures('Callithrix_Ct.png', callithix_df)

# %%
plot_figures('Alouatta_Ct.png', alouatta_df)

# %% [markdown]
# ### One hot encoding

# %%
nucleotides_df = seq_df.iloc[:, 4:]
nucleotides_df.replace('N', np.nan, inplace=True)
nucleotides_df.replace('-', np.nan, inplace=True)
nucleotides_df.head()
# Out:
#                                                        Season    1    2    3  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...  2016/2017  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...  2016/2017  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...  2017/2018  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...  2017/2018  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...  2016/2017  NaN  NaN  NaN
#
#                                                       4    5    6    7    8  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...  NaN  NaN  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...  NaN  NaN  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...  NaN  NaN  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...  NaN  NaN  NaN  NaN  NaN
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...  NaN  NaN  NaN  NaN  NaN
#
#                                                       9  ...  10131 10132  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...  NaN  ...      A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...  NaN  ...      A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...  NaN  ...      A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...  NaN  ...      A     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...  NaN  ...      A     C
#
#                                                    10133 10134 10135 10136  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...     A   NaN     C     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...     A   NaN     C     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...     A   NaN     C     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...     A   NaN     C     G
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...     A   NaN     C     G
#
#                                                    10137 10138 10139 10140
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...     C     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...     C     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...     C     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...     C     A     T     C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...     C     A     T     C
#
# [5 rows x 10141 columns]

# %%
nucleotides_ohe_df = pd.get_dummies(nucleotides_df)
nucleotides_ohe_df.head()
# Out:
#                                                     Season_2016/2017  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...                 1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...                 1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...                 0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...                 0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...                 1
#
#                                                     Season_2017/2018  1_A  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...                 0    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...                 0    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...                 1    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...                 1    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...                 0    0
#
#                                                     2_T  3_G  4_T  5_C  6_T  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...    0    0    0    0    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...    0    0    0    0    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...    0    0    0    0    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...    0    0    0    0    0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...    0    0    0    0    0
#
#                                                     7_G  8_G   ...     \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...    0    0   ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...    0    0   ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...    0    0   ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...    0    0   ...
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...    0    0   ...
#
#                                                     10132_C  10133_A  10134_C  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...        1        1        0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...        1        1        0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...        1        1        0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...        1        1        0
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...        1        1        0
#
#                                                     10134_T  10135_C  10136_G  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...        0        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...        0        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...        0        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...        0        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...        0        1        1
#
#                                                     10137_C  10138_A  10139_T  \
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...        1        1        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...        1        1        1
#
#                                                     10140_C
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY01|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY03|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY04|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY05|...        1
# 2019-01-30_ZIBRA2_YFV-RIO-Diferentes_CTs|RJY09|...        1
#
# [5 rows x 10554 columns]

# %%
seq_ohe_df = nucleotides_ohe_df

# %%
seq_ohe_df.insert(0, 'ID', seq_df['ID'])
seq_ohe_df.insert(1, 'Host', seq_df['Host'])
seq_ohe_df.insert(2, 'Ct', seq_df['Ct'])
seq_ohe_df.insert(3, 'Date', seq_df['Date'])

# %%
seq_ohe_df

# %%
seq_ohe_df['Host'].unique()

# %% [markdown]
# ### Save to .csv

# %%
seq_df.to_csv('../DATA/!CLEAN/dataframe_YFV_seqs_metadata.csv', index=True, header=True, decimal=',', sep=' ', float_format='%.2f')

# %%
seq_df.to_pickle('../DATA/!CLEAN/dataframe_YFV_seqs_metadata.pkl')

# %%
nucleotides_ohe_df.to_pickle('../DATA/!CLEAN/nucleotides_ohe_df.pkl')
