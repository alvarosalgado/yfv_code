# %%
# %matplotlib inline

from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.ensemble import RandomForestClassifier

import shap

# %%
#pd.set_option('display.max_rows', 500)

# %%
fasta_file = '../DATA/ZIBRA 2/RIO DE JANEIRO/Setembro-2018-WNV-CHIK-ZIKV/RESULTS/LIBRARY 1/CONSENSUS/YFV_RJ_library1_20180921.consensus.fasta'

# %% [markdown]
# ### different CTs

# %%
# Gets the sequences IDs
identifiers = [seq_record.id for seq_record in SeqIO.parse(fasta_file, "fasta")]

# %%
# Gets the sequences nucleotides
seqs = np.array([list(str(seq_rec.seq)) for seq_rec in SeqIO.parse(fasta_file, "fasta")])

# %%
# Creates columns names based on position, starting from 1, to make it consistent with the 
# sequence analysis, which starts at base number 1.
cols = list(range(1, seqs.shape[1]+1))

# %%
# Creates dataframe with data
df = pd.DataFrame(seqs, index=identifiers, columns=cols)

# %%
df['species'] = 'Leontopithecus rosalia'
df.loc['BC10_CHIKV_RJ_library1_20180921.primertrimmed.sorted.bam', 'Ct'] = 22
df.loc['BC11_CHIKV_RJ_library1_20180921.primertrimmed.sorted.bam', 'Ct'] = 12

# %%
df.head()
# Out:
#                                                     1  2  3  4  5  6  7  8  9  \
# BC10_CHIKV_RJ_library1_20180921.primertrimmed.s...  N  N  N  N  N  N  N  N  N
# BC11_CHIKV_RJ_library1_20180921.primertrimmed.s...  N  N  N  N  N  N  N  N  N
#
#                                                    10  ...  10232 10233 10234  \
# BC10_CHIKV_RJ_library1_20180921.primertrimmed.s...  N  ...      N     N     N
# BC11_CHIKV_RJ_library1_20180921.primertrimmed.s...  N  ...      N     N     N
#
#                                                    10235 10236 10237 10238  \
# BC10_CHIKV_RJ_library1_20180921.primertrimmed.s...     N     N     N     N
# BC11_CHIKV_RJ_library1_20180921.primertrimmed.s...     N     N     N     N
#
#                                                    10239  \
# BC10_CHIKV_RJ_library1_20180921.primertrimmed.s...     N
# BC11_CHIKV_RJ_library1_20180921.primertrimmed.s...     N
#
#                                                                    species  \
# BC10_CHIKV_RJ_library1_20180921.primertrimmed.s...  Leontopithecus rosalia
# BC11_CHIKV_RJ_library1_20180921.primertrimmed.s...  Leontopithecus rosalia
#
#                                                       Ct
# BC10_CHIKV_RJ_library1_20180921.primertrimmed.s...  22.0
# BC11_CHIKV_RJ_library1_20180921.primertrimmed.s...  12.0
#
# [2 rows x 10241 columns]

# %%
df_NHP = df.join(samples)
df_NHP
# Out:
#                                                     1  2  3  4  5  6  7  8  9  \
# NC|ES504|NHPrimate|DomingosMartins|EspiritoSant...  A  T  G  T  C  T  G  G  T
# NC|ES505|NHPrimate|DomingosMartins|EspiritoSant...  A  T  G  T  C  T  G  G  T
# FioRJ|Library9YIBRA_M218_2176|Primate|Bahia|10-...  N  N  N  N  N  N  N  N  N
# FioRJ|460|Human|MinasGerais_NovoCruzeiro|30-01-...  -  -  -  -  -  -  -  -  -
# FioRJ|1818|Human|EspiritoSanto_Cariacia|10-03-2017  -  -  -  -  -  -  -  -  -
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  -  -  -  -  -  -  -  -  -
# FioRJ|3919|Human|EspiritoSanto_DomingosMartins|...  -  -  -  -  -  -  -  -  -
# FioRJ|438|Monkey|Espirito_Santo_DomingosMartins...  -  -  -  T  C  T  G  G  T
# FioRJ|465|Human|MinasGerais_Itambacuri|30-01-2017   -  -  -  -  -  -  -  -  -
# FioRJ|480|Human|MinasGerais_TeofiloOtoni|28-01-...  -  -  -  -  -  -  -  -  -
# FioRJ|532|Monkey|MinasGerais_CoronelMurta|13-01...  -  -  -  -  -  T  G  G  T
# FioRJ|1536|Human|EspiritoSanto_Vitoria|22-02-2017   G  -  G  T  C  T  G  G  T
# FioRJ|2109|Monkey|EspiritoSanto_Cariacica|08-03...  -  -  -  -  -  -  -  -  -
# FioRJ|4278|Monkey|RioJaneiro_Marica|17-04-2017      -  -  G  T  C  T  G  G  T
# FioRJ|4480|Human|RioJaneiro_CasimirodeAbreu|22-...  -  -  -  -  -  -  -  -  -
# IAL_11|Primate|EspiritoSanto_VendaNovadoImigran...  A  -  G  -  -  T  G  G  T
# IAL_8|Primate|EspiritoSanto_Itarana|24-01-2017      A  T  G  T  C  T  G  G  T
# M105_libraryYIBRA8|Human|MinasGerais_PiedadeCar...  N  N  G  T  C  T  G  G  T
# M107_library4|Human|MinasGerais|NovoCruzeiro|30...  N  N  G  T  C  T  G  G  T
# M11_library4|Primate_Cebidae|MinasGerais_Caldas...  N  N  G  T  C  T  G  G  T
# M123_libraryYIBRA8|Human|MinasGerais_Itambaquri...  N  N  G  T  C  T  G  G  T
# M164_libraryYIBRA8|Human|MinasGerais_Simonesia|...  N  N  G  T  C  T  G  G  T
# M16_libraryYIBRA8|Human|MinasGerais_Caratinga|0...  N  N  G  T  C  T  G  G  T
# M18_library2|Human|MinasGerais_Itambacuri|21-01...  N  N  G  T  C  T  G  G  T
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  N  N  G  T  C  T  G  G  T
# M211_libraryX|Primate_AlouattaFuscaClamitans|Mi...  N  N  G  T  C  T  G  G  T
# M25_library1|Human|MinasGerais_NovoCruzeiro|25-...  N  N  G  T  C  T  N  G  T
# M48_library4|Human|MinasGerais_Ladainha|07-01-2017  N  N  G  T  C  T  G  G  T
# M51_libraryYIBRA8|Human|MinasGerais_NovoCruzeir...  N  N  G  T  C  T  G  G  T
# M58_libraryYIBRA8|Human|MinasGerais_Itambaquri|...  N  N  G  T  C  T  G  G  T
# ...                                                .. .. .. .. .. .. .. .. ..
# M9_library4|Monkey|MinasGerais_OuroFino|15-02-2017  N  N  G  T  C  T  G  G  T
# M7_library2|Primate_Cebidae|MinasGerais_Delfino...  N  N  G  T  C  T  G  G  T
# M43_libraryY|Human|MinasGerais_Pote|18-01-2017      N  N  N  N  N  N  N  N  N
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  N  N  G  T  C  T  G  G  T
# M5_library2|Primate_AllouataGuaribaClamitans|Mi...  N  N  G  T  C  T  G  G  T
# M216_libraryX|Primate_CallicebusSp|MinasGerais_...  N  N  N  T  C  T  N  G  T
# M217_libraryX|Primate_CebidaeSpp|MinaisGerais_N...  N  N  G  T  C  T  G  G  T
# M138_libraryX|Human|MinasGerais_SantaBarbaradoL...  N  N  G  T  C  T  G  G  T
# M17_library1|Human|MinasGerais_Ladainha|14-01-2017  N  N  N  N  N  N  N  G  T
# M100_library6|Human|MinasGerais|Ladainha|02-01-...  N  N  G  T  C  T  G  G  T
# M26_library5and6|Human|MinasGerais_SaoCaetanoDo...  N  N  G  T  C  T  G  G  T
# M98_library6|Human|MinasGerais|TeofiloOtoni|10-...  N  N  G  T  C  T  G  G  T
# M99_library6|Human|MinasGerais|TeofiloOtoni|21-...  N  N  G  T  C  T  G  G  T
# M35_library3|Human|MinasGerais_TeofiloOtoni|20-...  N  N  G  T  C  T  G  G  T
# M36_library3|MinasGerais|NovoCruzeiro|14-01-2017    N  N  G  T  C  T  G  G  T
# M73_library5|PrimateCebidae|MinasGerais_Aguanil...  N  N  G  T  C  T  G  G  T
# M96_library5and6|Human|MinasGerais|Ladainha|19-...  N  N  N  N  N  N  N  N  N
# RJ168|NHP|Divinopolis-MG|2017-01-23                 -  -  -  -  -  -  -  -  -
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               -  -  -  -  -  -  -  -  -
# RJ171|NHP|SaoRoqueMinas-MG|2017-02-03               -  -  -  -  -  -  -  -  -
# RJ148|Human|TeofiloOtoni-MG|2017-01-24              -  -  -  -  -  -  -  -  -
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23               -  -  -  -  -  -  -  -  -
# RJ185|Human|SaoJoaoEvangelista-MG|2017-01-22        -  -  -  -  -  -  -  -  -
# RJ150|Human|TeofiloOtoni-MG|2017-01-27              -  -  -  -  -  -  -  -  -
# RJ163|NHP|Sacramento-MG|2017-02-09                  -  -  -  -  -  -  -  -  -
# RJ164|NHP|Juatuba-MG|2017-02-14                     -  -  -  -  -  -  -  -  -
# RJ157|Human|TeofiloOtoni-MG|2017-02-05              -  -  -  -  -  -  -  -  -
# RJ151|NHP|Itamarandiba-MG|2017-01-13                -  -  -  -  -  -  -  -  -
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24          -  -  -  -  -  -  -  -  -
# MF170971|Monkey|MinasGerais_SaoRoqueDeMinas|NA|...  A  T  G  T  C  T  G  G  T
#
#                                                    10  ...  10194 10195 10196  \
# NC|ES504|NHPrimate|DomingosMartins|EspiritoSant...  C  ...      G     T     A
# NC|ES505|NHPrimate|DomingosMartins|EspiritoSant...  C  ...      G     T     A
# FioRJ|Library9YIBRA_M218_2176|Primate|Bahia|10-...  N  ...      N     N     N
# FioRJ|460|Human|MinasGerais_NovoCruzeiro|30-01-...  -  ...      G     T     A
# FioRJ|1818|Human|EspiritoSanto_Cariacia|10-03-2017  -  ...      G     T     A
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  -  ...      G     T     A
# FioRJ|3919|Human|EspiritoSanto_DomingosMartins|...  -  ...      G     T     A
# FioRJ|438|Monkey|Espirito_Santo_DomingosMartins...  C  ...      G     T     A
# FioRJ|465|Human|MinasGerais_Itambacuri|30-01-2017   -  ...      G     T     A
# FioRJ|480|Human|MinasGerais_TeofiloOtoni|28-01-...  -  ...      G     T     A
# FioRJ|532|Monkey|MinasGerais_CoronelMurta|13-01...  C  ...      G     T     A
# FioRJ|1536|Human|EspiritoSanto_Vitoria|22-02-2017   C  ...      G     T     A
# FioRJ|2109|Monkey|EspiritoSanto_Cariacica|08-03...  -  ...      G     T     A
# FioRJ|4278|Monkey|RioJaneiro_Marica|17-04-2017      C  ...      G     T     A
# FioRJ|4480|Human|RioJaneiro_CasimirodeAbreu|22-...  -  ...      G     T     A
# IAL_11|Primate|EspiritoSanto_VendaNovadoImigran...  C  ...      G     T     A
# IAL_8|Primate|EspiritoSanto_Itarana|24-01-2017      C  ...      G     T     A
# M105_libraryYIBRA8|Human|MinasGerais_PiedadeCar...  C  ...      G     T     A
# M107_library4|Human|MinasGerais|NovoCruzeiro|30...  C  ...      G     T     A
# M11_library4|Primate_Cebidae|MinasGerais_Caldas...  C  ...      G     T     A
# M123_libraryYIBRA8|Human|MinasGerais_Itambaquri...  C  ...      G     T     A
# M164_libraryYIBRA8|Human|MinasGerais_Simonesia|...  C  ...      G     T     A
# M16_libraryYIBRA8|Human|MinasGerais_Caratinga|0...  C  ...      G     T     A
# M18_library2|Human|MinasGerais_Itambacuri|21-01...  C  ...      G     T     A
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  C  ...      G     T     A
# M211_libraryX|Primate_AlouattaFuscaClamitans|Mi...  C  ...      G     T     A
# M25_library1|Human|MinasGerais_NovoCruzeiro|25-...  C  ...      N     N     N
# M48_library4|Human|MinasGerais_Ladainha|07-01-2017  C  ...      G     T     A
# M51_libraryYIBRA8|Human|MinasGerais_NovoCruzeir...  C  ...      G     T     A
# M58_libraryYIBRA8|Human|MinasGerais_Itambaquri|...  C  ...      G     T     A
# ...                                                ..  ...    ...   ...   ...
# M9_library4|Monkey|MinasGerais_OuroFino|15-02-2017  C  ...      G     T     A
# M7_library2|Primate_Cebidae|MinasGerais_Delfino...  C  ...      G     T     A
# M43_libraryY|Human|MinasGerais_Pote|18-01-2017      N  ...      N     N     N
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  C  ...      G     T     A
# M5_library2|Primate_AllouataGuaribaClamitans|Mi...  C  ...      G     T     A
# M216_libraryX|Primate_CallicebusSp|MinasGerais_...  C  ...      G     T     A
# M217_libraryX|Primate_CebidaeSpp|MinaisGerais_N...  C  ...      G     T     A
# M138_libraryX|Human|MinasGerais_SantaBarbaradoL...  C  ...      G     T     A
# M17_library1|Human|MinasGerais_Ladainha|14-01-2017  C  ...      N     N     N
# M100_library6|Human|MinasGerais|Ladainha|02-01-...  C  ...      G     T     A
# M26_library5and6|Human|MinasGerais_SaoCaetanoDo...  C  ...      G     T     A
# M98_library6|Human|MinasGerais|TeofiloOtoni|10-...  C  ...      G     T     A
# M99_library6|Human|MinasGerais|TeofiloOtoni|21-...  C  ...      G     T     A
# M35_library3|Human|MinasGerais_TeofiloOtoni|20-...  C  ...      G     T     A
# M36_library3|MinasGerais|NovoCruzeiro|14-01-2017    C  ...      G     T     A
# M73_library5|PrimateCebidae|MinasGerais_Aguanil...  C  ...      G     T     A
# M96_library5and6|Human|MinasGerais|Ladainha|19-...  N  ...      N     N     N
# RJ168|NHP|Divinopolis-MG|2017-01-23                 -  ...      -     -     -
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               -  ...      -     -     -
# RJ171|NHP|SaoRoqueMinas-MG|2017-02-03               -  ...      -     -     -
# RJ148|Human|TeofiloOtoni-MG|2017-01-24              -  ...      -     -     -
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23               -  ...      -     -     -
# RJ185|Human|SaoJoaoEvangelista-MG|2017-01-22        -  ...      -     -     -
# RJ150|Human|TeofiloOtoni-MG|2017-01-27              -  ...      -     -     -
# RJ163|NHP|Sacramento-MG|2017-02-09                  -  ...      -     -     -
# RJ164|NHP|Juatuba-MG|2017-02-14                     -  ...      -     -     -
# RJ157|Human|TeofiloOtoni-MG|2017-02-05              -  ...      -     -     -
# RJ151|NHP|Itamarandiba-MG|2017-01-13                -  ...      -     -     -
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24          -  ...      -     -     -
# MF170971|Monkey|MinasGerais_SaoRoqueDeMinas|NA|...  C  ...      G     T     A
#
#                                                    10197 10198 10199 10200  \
# NC|ES504|NHPrimate|DomingosMartins|EspiritoSant...     C     T     C     T
# NC|ES505|NHPrimate|DomingosMartins|EspiritoSant...     C     T     C     T
# FioRJ|Library9YIBRA_M218_2176|Primate|Bahia|10-...     N     N     N     N
# FioRJ|460|Human|MinasGerais_NovoCruzeiro|30-01-...     C     T     C     T
# FioRJ|1818|Human|EspiritoSanto_Cariacia|10-03-2017     C     T     C     T
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...     C     T     C     T
# FioRJ|3919|Human|EspiritoSanto_DomingosMartins|...     C     T     C     T
# FioRJ|438|Monkey|Espirito_Santo_DomingosMartins...     C     T     C     T
# FioRJ|465|Human|MinasGerais_Itambacuri|30-01-2017      C     T     C     T
# FioRJ|480|Human|MinasGerais_TeofiloOtoni|28-01-...     C     T     C     T
# FioRJ|532|Monkey|MinasGerais_CoronelMurta|13-01...     C     T     C     T
# FioRJ|1536|Human|EspiritoSanto_Vitoria|22-02-2017      C     T     C     T
# FioRJ|2109|Monkey|EspiritoSanto_Cariacica|08-03...     C     T     C     T
# FioRJ|4278|Monkey|RioJaneiro_Marica|17-04-2017         C     T     C     T
# FioRJ|4480|Human|RioJaneiro_CasimirodeAbreu|22-...     C     T     C     T
# IAL_11|Primate|EspiritoSanto_VendaNovadoImigran...     C     T     C     T
# IAL_8|Primate|EspiritoSanto_Itarana|24-01-2017         C     T     C     T
# M105_libraryYIBRA8|Human|MinasGerais_PiedadeCar...     C     T     C     T
# M107_library4|Human|MinasGerais|NovoCruzeiro|30...     C     T     C     T
# M11_library4|Primate_Cebidae|MinasGerais_Caldas...     C     T     C     T
# M123_libraryYIBRA8|Human|MinasGerais_Itambaquri...     C     T     C     T
# M164_libraryYIBRA8|Human|MinasGerais_Simonesia|...     C     T     C     T
# M16_libraryYIBRA8|Human|MinasGerais_Caratinga|0...     C     T     C     T
# M18_library2|Human|MinasGerais_Itambacuri|21-01...     C     T     C     T
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...     C     T     C     T
# M211_libraryX|Primate_AlouattaFuscaClamitans|Mi...     C     T     C     T
# M25_library1|Human|MinasGerais_NovoCruzeiro|25-...     N     N     N     N
# M48_library4|Human|MinasGerais_Ladainha|07-01-2017     C     T     C     T
# M51_libraryYIBRA8|Human|MinasGerais_NovoCruzeir...     C     T     C     T
# M58_libraryYIBRA8|Human|MinasGerais_Itambaquri|...     C     T     C     T
# ...                                                  ...   ...   ...   ...
# M9_library4|Monkey|MinasGerais_OuroFino|15-02-2017     C     T     C     T
# M7_library2|Primate_Cebidae|MinasGerais_Delfino...     C     T     C     T
# M43_libraryY|Human|MinasGerais_Pote|18-01-2017         N     N     N     N
# M83_library3|Primate_Callitrix|MinasGerais_Lada...     C     T     C     T
# M5_library2|Primate_AllouataGuaribaClamitans|Mi...     C     T     C     T
# M216_libraryX|Primate_CallicebusSp|MinasGerais_...     N     T     C     T
# M217_libraryX|Primate_CebidaeSpp|MinaisGerais_N...     C     T     C     T
# M138_libraryX|Human|MinasGerais_SantaBarbaradoL...     C     T     C     T
# M17_library1|Human|MinasGerais_Ladainha|14-01-2017     N     N     N     N
# M100_library6|Human|MinasGerais|Ladainha|02-01-...     C     T     C     T
# M26_library5and6|Human|MinasGerais_SaoCaetanoDo...     C     T     C     T
# M98_library6|Human|MinasGerais|TeofiloOtoni|10-...     C     T     C     T
# M99_library6|Human|MinasGerais|TeofiloOtoni|21-...     C     T     C     T
# M35_library3|Human|MinasGerais_TeofiloOtoni|20-...     C     T     C     T
# M36_library3|MinasGerais|NovoCruzeiro|14-01-2017       C     T     C     T
# M73_library5|PrimateCebidae|MinasGerais_Aguanil...     C     T     C     T
# M96_library5and6|Human|MinasGerais|Ladainha|19-...     N     N     N     N
# RJ168|NHP|Divinopolis-MG|2017-01-23                    -     -     -     -
# RJ143|NHP|BeloHorizonte-MG|2017-01-24                  -     -     -     -
# RJ171|NHP|SaoRoqueMinas-MG|2017-02-03                  -     -     -     -
# RJ148|Human|TeofiloOtoni-MG|2017-01-24                 -     -     -     -
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23                  -     -     -     -
# RJ185|Human|SaoJoaoEvangelista-MG|2017-01-22           -     -     -     -
# RJ150|Human|TeofiloOtoni-MG|2017-01-27                 -     -     -     -
# RJ163|NHP|Sacramento-MG|2017-02-09                     -     -     -     -
# RJ164|NHP|Juatuba-MG|2017-02-14                        -     -     -     -
# RJ157|Human|TeofiloOtoni-MG|2017-02-05                 -     -     -     -
# RJ151|NHP|Itamarandiba-MG|2017-01-13                   -     -     -     -
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24             -     -     -     -
# MF170971|Monkey|MinasGerais_SaoRoqueDeMinas|NA|...     C     T     C     T
#
#                                                           Host       Date  \
# NC|ES504|NHPrimate|DomingosMartins|EspiritoSant...         NaN        NaT
# NC|ES505|NHPrimate|DomingosMartins|EspiritoSant...         NaN        NaT
# FioRJ|Library9YIBRA_M218_2176|Primate|Bahia|10-...         NaN        NaT
# FioRJ|460|Human|MinasGerais_NovoCruzeiro|30-01-...         NaN        NaT
# FioRJ|1818|Human|EspiritoSanto_Cariacia|10-03-2017         NaN        NaT
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  Callithrix 2017-03-09
# FioRJ|3919|Human|EspiritoSanto_DomingosMartins|...         NaN        NaT
# FioRJ|438|Monkey|Espirito_Santo_DomingosMartins...   NHP (unk) 2017-01-31
# FioRJ|465|Human|MinasGerais_Itambacuri|30-01-2017          NaN        NaT
# FioRJ|480|Human|MinasGerais_TeofiloOtoni|28-01-...         NaN        NaT
# FioRJ|532|Monkey|MinasGerais_CoronelMurta|13-01...    Alouatta 2017-01-13
# FioRJ|1536|Human|EspiritoSanto_Vitoria|22-02-2017          NaN        NaT
# FioRJ|2109|Monkey|EspiritoSanto_Cariacica|08-03...    Alouatta 2017-03-08
# FioRJ|4278|Monkey|RioJaneiro_Marica|17-04-2017        Alouatta 2017-04-17
# FioRJ|4480|Human|RioJaneiro_CasimirodeAbreu|22-...         NaN        NaT
# IAL_11|Primate|EspiritoSanto_VendaNovadoImigran...   NHP (unk) 2017-01-24
# IAL_8|Primate|EspiritoSanto_Itarana|24-01-2017       NHP (unk) 2017-01-24
# M105_libraryYIBRA8|Human|MinasGerais_PiedadeCar...         NaN        NaT
# M107_library4|Human|MinasGerais|NovoCruzeiro|30...         NaN        NaT
# M11_library4|Primate_Cebidae|MinasGerais_Caldas...     Cebidae 2017-02-13
# M123_libraryYIBRA8|Human|MinasGerais_Itambaquri...         NaN        NaT
# M164_libraryYIBRA8|Human|MinasGerais_Simonesia|...         NaN        NaT
# M16_libraryYIBRA8|Human|MinasGerais_Caratinga|0...         NaN        NaT
# M18_library2|Human|MinasGerais_Itambacuri|21-01...         NaN        NaT
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  Callithrix 2017-01-19
# M211_libraryX|Primate_AlouattaFuscaClamitans|Mi...    Alouatta 2017-01-13
# M25_library1|Human|MinasGerais_NovoCruzeiro|25-...         NaN        NaT
# M48_library4|Human|MinasGerais_Ladainha|07-01-2017         NaN        NaT
# M51_libraryYIBRA8|Human|MinasGerais_NovoCruzeir...         NaN        NaT
# M58_libraryYIBRA8|Human|MinasGerais_Itambaquri|...         NaN        NaT
# ...                                                        ...        ...
# M9_library4|Monkey|MinasGerais_OuroFino|15-02-2017    Alouatta 2017-02-15
# M7_library2|Primate_Cebidae|MinasGerais_Delfino...     Cebidae 2017-02-14
# M43_libraryY|Human|MinasGerais_Pote|18-01-2017             NaN        NaT
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  Callithrix 2017-02-09
# M5_library2|Primate_AllouataGuaribaClamitans|Mi...    Alouatta 2017-02-15
# M216_libraryX|Primate_CallicebusSp|MinasGerais_...  Callicebus 2017-01-25
# M217_libraryX|Primate_CebidaeSpp|MinaisGerais_N...     Cebidae 2017-01-25
# M138_libraryX|Human|MinasGerais_SantaBarbaradoL...         NaN        NaT
# M17_library1|Human|MinasGerais_Ladainha|14-01-2017         NaN        NaT
# M100_library6|Human|MinasGerais|Ladainha|02-01-...         NaN        NaT
# M26_library5and6|Human|MinasGerais_SaoCaetanoDo...         NaN        NaT
# M98_library6|Human|MinasGerais|TeofiloOtoni|10-...         NaN        NaT
# M99_library6|Human|MinasGerais|TeofiloOtoni|21-...         NaN        NaT
# M35_library3|Human|MinasGerais_TeofiloOtoni|20-...         NaN        NaT
# M36_library3|MinasGerais|NovoCruzeiro|14-01-2017           NaN        NaT
# M73_library5|PrimateCebidae|MinasGerais_Aguanil...     Cebidae 2017-02-22
# M96_library5and6|Human|MinasGerais|Ladainha|19-...         NaN        NaT
# RJ168|NHP|Divinopolis-MG|2017-01-23                   Alouatta 2017-01-23
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               Callithrix 2017-01-24
# RJ171|NHP|SaoRoqueMinas-MG|2017-02-03                NHP (unk) 2017-02-03
# RJ148|Human|TeofiloOtoni-MG|2017-01-24                     NaN        NaT
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23               Callithrix 2017-02-03
# RJ185|Human|SaoJoaoEvangelista-MG|2017-01-22               NaN        NaT
# RJ150|Human|TeofiloOtoni-MG|2017-01-27                     NaN        NaT
# RJ163|NHP|Sacramento-MG|2017-02-09                  Callithrix 2017-02-09
# RJ164|NHP|Juatuba-MG|2017-02-14                      NHP (unk) 2017-02-14
# RJ157|Human|TeofiloOtoni-MG|2017-02-05                     NaN        NaT
# RJ151|NHP|Itamarandiba-MG|2017-01-13                 NHP (unk) 2017-01-13
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24          Callithrix 2017-01-24
# MF170971|Monkey|MinasGerais_SaoRoqueDeMinas|NA|...         NaN        NaT
#
#                                                       Ct
# NC|ES504|NHPrimate|DomingosMartins|EspiritoSant...   NaN
# NC|ES505|NHPrimate|DomingosMartins|EspiritoSant...   NaN
# FioRJ|Library9YIBRA_M218_2176|Primate|Bahia|10-...   NaN
# FioRJ|460|Human|MinasGerais_NovoCruzeiro|30-01-...   NaN
# FioRJ|1818|Human|EspiritoSanto_Cariacia|10-03-2017   NaN
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  11.0
# FioRJ|3919|Human|EspiritoSanto_DomingosMartins|...   NaN
# FioRJ|438|Monkey|Espirito_Santo_DomingosMartins...  19.0
# FioRJ|465|Human|MinasGerais_Itambacuri|30-01-2017    NaN
# FioRJ|480|Human|MinasGerais_TeofiloOtoni|28-01-...   NaN
# FioRJ|532|Monkey|MinasGerais_CoronelMurta|13-01...   8.0
# FioRJ|1536|Human|EspiritoSanto_Vitoria|22-02-2017    NaN
# FioRJ|2109|Monkey|EspiritoSanto_Cariacica|08-03...   7.0
# FioRJ|4278|Monkey|RioJaneiro_Marica|17-04-2017      11.0
# FioRJ|4480|Human|RioJaneiro_CasimirodeAbreu|22-...   NaN
# IAL_11|Primate|EspiritoSanto_VendaNovadoImigran...  13.0
# IAL_8|Primate|EspiritoSanto_Itarana|24-01-2017      12.0
# M105_libraryYIBRA8|Human|MinasGerais_PiedadeCar...   NaN
# M107_library4|Human|MinasGerais|NovoCruzeiro|30...   NaN
# M11_library4|Primate_Cebidae|MinasGerais_Caldas...   6.0
# M123_libraryYIBRA8|Human|MinasGerais_Itambaquri...   NaN
# M164_libraryYIBRA8|Human|MinasGerais_Simonesia|...   NaN
# M16_libraryYIBRA8|Human|MinasGerais_Caratinga|0...   NaN
# M18_library2|Human|MinasGerais_Itambacuri|21-01...   NaN
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  12.0
# M211_libraryX|Primate_AlouattaFuscaClamitans|Mi...   9.0
# M25_library1|Human|MinasGerais_NovoCruzeiro|25-...   NaN
# M48_library4|Human|MinasGerais_Ladainha|07-01-2017   NaN
# M51_libraryYIBRA8|Human|MinasGerais_NovoCruzeir...   NaN
# M58_libraryYIBRA8|Human|MinasGerais_Itambaquri|...   NaN
# ...                                                  ...
# M9_library4|Monkey|MinasGerais_OuroFino|15-02-2017  11.0
# M7_library2|Primate_Cebidae|MinasGerais_Delfino...   6.0
# M43_libraryY|Human|MinasGerais_Pote|18-01-2017       NaN
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  12.0
# M5_library2|Primate_AllouataGuaribaClamitans|Mi...  11.0
# M216_libraryX|Primate_CallicebusSp|MinasGerais_...  14.0
# M217_libraryX|Primate_CebidaeSpp|MinaisGerais_N...  11.0
# M138_libraryX|Human|MinasGerais_SantaBarbaradoL...   NaN
# M17_library1|Human|MinasGerais_Ladainha|14-01-2017   NaN
# M100_library6|Human|MinasGerais|Ladainha|02-01-...   NaN
# M26_library5and6|Human|MinasGerais_SaoCaetanoDo...   NaN
# M98_library6|Human|MinasGerais|TeofiloOtoni|10-...   NaN
# M99_library6|Human|MinasGerais|TeofiloOtoni|21-...   NaN
# M35_library3|Human|MinasGerais_TeofiloOtoni|20-...   NaN
# M36_library3|MinasGerais|NovoCruzeiro|14-01-2017     NaN
# M73_library5|PrimateCebidae|MinasGerais_Aguanil...  14.0
# M96_library5and6|Human|MinasGerais|Ladainha|19-...   NaN
# RJ168|NHP|Divinopolis-MG|2017-01-23                 18.0
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               10.0
# RJ171|NHP|SaoRoqueMinas-MG|2017-02-03                9.0
# RJ148|Human|TeofiloOtoni-MG|2017-01-24               NaN
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23                8.9
# RJ185|Human|SaoJoaoEvangelista-MG|2017-01-22         NaN
# RJ150|Human|TeofiloOtoni-MG|2017-01-27               NaN
# RJ163|NHP|Sacramento-MG|2017-02-09                  13.0
# RJ164|NHP|Juatuba-MG|2017-02-14                     10.6
# RJ157|Human|TeofiloOtoni-MG|2017-02-05               NaN
# RJ151|NHP|Itamarandiba-MG|2017-01-13                 8.8
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24           8.6
# MF170971|Monkey|MinasGerais_SaoRoqueDeMinas|NA|...   NaN
#
# [65 rows x 10203 columns]

# %%
df_Callithrix = df_NHP[df_NHP['Host'] == 'Callithrix']
df_Callithrix
# Out:
#                                                     1  2  3  4  5  6  7  8  9  \
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  -  -  -  -  -  -  -  -  -
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  N  N  G  T  C  T  G  G  T
# M78_library4|Primate_CallithrixPenicillata|Mina...  N  N  G  T  C  T  G  G  T
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  N  N  G  T  C  T  G  G  T
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               -  -  -  -  -  -  -  -  -
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23               -  -  -  -  -  -  -  -  -
# RJ163|NHP|Sacramento-MG|2017-02-09                  -  -  -  -  -  -  -  -  -
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24          -  -  -  -  -  -  -  -  -
#
#                                                    10  ...  10194 10195 10196  \
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  -  ...      G     T     A
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  C  ...      G     T     A
# M78_library4|Primate_CallithrixPenicillata|Mina...  C  ...      G     T     A
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  C  ...      G     T     A
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               -  ...      -     -     -
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23               -  ...      -     -     -
# RJ163|NHP|Sacramento-MG|2017-02-09                  -  ...      -     -     -
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24          -  ...      -     -     -
#
#                                                    10197 10198 10199 10200  \
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...     C     T     C     T
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...     C     T     C     T
# M78_library4|Primate_CallithrixPenicillata|Mina...     C     T     C     T
# M83_library3|Primate_Callitrix|MinasGerais_Lada...     C     T     C     T
# RJ143|NHP|BeloHorizonte-MG|2017-01-24                  -     -     -     -
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23                  -     -     -     -
# RJ163|NHP|Sacramento-MG|2017-02-09                     -     -     -     -
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24             -     -     -     -
#
#                                                           Host       Date  \
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  Callithrix 2017-03-09
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  Callithrix 2017-01-19
# M78_library4|Primate_CallithrixPenicillata|Mina...  Callithrix 2017-02-20
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  Callithrix 2017-02-09
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               Callithrix 2017-01-24
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23               Callithrix 2017-02-03
# RJ163|NHP|Sacramento-MG|2017-02-09                  Callithrix 2017-02-09
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24          Callithrix 2017-01-24
#
#                                                       Ct
# FioRJ|2115|Monkey|EspiritoSanto_Cariacia|09-03-...  11.0
# M210_libraryX|Primate_Callithrix_geoffroyi|Mina...  12.0
# M78_library4|Primate_CallithrixPenicillata|Mina...  12.0
# M83_library3|Primate_Callitrix|MinasGerais_Lada...  12.0
# RJ143|NHP|BeloHorizonte-MG|2017-01-24               10.0
# RJ162|NHP|ChapadaGaucha-MG|2017-01-23                8.9
# RJ163|NHP|Sacramento-MG|2017-02-09                  13.0
# RJ153|NHP|FelicianoDosSantos-MG|2017-01-24           8.6
#
# [8 rows x 10203 columns]

# %% [markdown]
# # _"Class"_ vector
# Insert a column named _"class"_ in each of the dataframes, indicating to which class they belong. This is the "y" value for the classification algorithm.
#
# In the present analysis, it is hypothesized that genomes from Africa and Asia did not cause microcephaly, and genomes from Oceania (French Polynesia and Micronesia) and the Americas did cause such neurological diseases. Therefore, we investigate significant differences between these two groups.
#
# - Africa and Asia are class 0.
# - Oceania and Americas are class 1.

# %%
df_americas['class'] = np.ones(len(df_americas))
# df_americas.head()

# %%
df_oceania['class'] = np.ones(len(df_oceania))
#df_oceania.tail()

# %%
df_asia['class'] = np.zeros(len(df_asia))
#df_asia.tail()

# %%
df_africa['class'] = np.zeros(len(df_africa))
#df_africa.tail()

# %% [markdown]
# # Full dataset creation
#
# Append all regions together in one `DataFrame`

# %%
df = df_americas.append([df_oceania, df_asia, df_africa])
#df

# %% [markdown]
# # One-Hot Encoding
#
# Since genomic data is categorical (ACGT), it must be prepared in a way suitable for ML algorithms, i.e., numerical.
#
# Pandas `pd.get_dummies(df)` method applies "one-hot encoding" to the data, transforming each categorical attribute column (with n categories) into n columns with 0's and 1's. It contains 0's in all positions, except for the one corresponding to the value present in that attribute. See below:
#
# This dataset
#
# |sample|base1|base2|
# |------|-----|-----|
# |s_1   |A    |T    |
# |s_2   |A    |G    |
# |s_3   |C    |T    |
#
# Becomes
#
# |sample|base1_A|base1_C|base1_G|base1_T|base2_A|base2_C|base2_G|base2_T|
# |------|-------|-------|-------|-------|-------|-------|-------|-------|
# |s_1   |1      |0      |0      |0      |0      |0      |0      |1      |
# |s_2   |1      |0      |0      |0      |0      |0      |1      |0      |
# |s_3   |0      |1      |0      |0      |0      |0      |0      |1      |

# %%
df_ohe = pd.get_dummies(df)

# %%
#df_ohe.describe()

# %%
#df_ohe.head()

# %% [markdown]
# ### Save data to disk
# Save DataFrames for later use. Saves time

# %%
df_ohe.to_pickle('./df_ohe.pkl')

# %%
df_ohe = pd.read_pickle('./df_ohe.pkl')

# %% [markdown]
# # Create training and target sets

# %%
X = df_ohe.drop('class', axis=1)
y = df_ohe['class']

# %% [markdown]
# # Random Forest Classifier
#
# Based on experience, we will use a random forest with 100 trees (we comparer `oob_score_` values for different numbers of trees).
#
# Set `random state = 0` and `oob_score = True` to allow reproducibility and to use "out of bag" samples to compute accuracy.

# %%
#clf = RandomForestClassifier(n_estimators=100, random_state=0, oob_score=True)

# %%
#clf.fit(X, y)

# %%
#clf.oob_score_

# %%
#predictions = clf.predict(X)
#predictions == Y.values

# %% [markdown]
# ### Save classifier
# Save trained classifier to disk to avoid re-training every time the notebook is run.

# %%
from sklearn.externals import joblib
#joblib.dump(clf, 'saved_random_forest.joblib');

# %%
clf = joblib.load('saved_random_forest.joblib')
print("oob score: ", clf.oob_score_)
clf
# Out:
# oob score:  0.967741935483871
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=True, random_state=0, verbose=0, warm_start=False)

# %% [markdown]
# # Feature importances
#
# Below is a list containing the feature importances as obtained by the random forest, using SciKit Learn's built-in feature importance measurement. This analyses the impurity decrease for every node of every tree, and computes each attribute's contribution in the forest. An explanation can be found #here [link to page explaining]().
#
# However, as pointed out in [this study](), this approach to variable importance might not be the most adequate. It can be inconsistent and/or misleading in some cases.
#
# Therefore, we will later use another approach to variable importance (see SHAP below)

# %%
imp = clf.feature_importances_
attr = X.columns

# %%
ohe_importances = pd.Series(imp, index=attr)
#ohe_importances.head()
ohe_importances.shape

# %% [markdown]
# # From one-hot encoding to original features' names.
# Since "ohe" creates additional columns to accomodate the attributes' categories, we have to go back to the original attribute's names in order to clearly analyse the results, especially where it concerns feature importances.

# %%
import re
pattern = "^\d+"
dic={}

# %%
# The code below sums the importances for each category in each attribute.
for pos in ohe_importances.index:
    attr = re.match(pattern, pos).group()
    if attr not in dic.keys():
        dic[attr] = ohe_importances[pos]
    else:
        dic[attr] += ohe_importances[pos]

# %%
original_importances = pd.Series(dic)
original_importances_sorted = original_importances.sort_values(ascending=False)
original_importances_sorted

# %%
max_imp = original_importances.max()
original_index = original_importances.index
loc = pd.Index(original_importances).get_loc(max_imp)
max_pos = original_index[loc]

# %%
imp_threshold = 0.01

# %%
major_importances = original_importances[original_importances > imp_threshold]

# %%
major_importances.sum()

# %%
print('The position with highest importance is nucleotide n{0}, with {1}'.format(max_pos, max_imp))

# %%
locs = np.where(original_importances > imp_threshold)
positions = original_index[locs]
print(positions)

# %%
len(positions)

# %%
plt.scatter(positions, original_importances[positions]);

# %% [markdown]
# # Location on the genome
# The positions above are the ones that have the largest influence on the classification results.
# Together, they account for {{"%.2f" % (100 * major_importances.sum()) + "\%"}} of the prediction capacity.
#
# However, when we look at where they are located in the genome, most of them are in the 3rd position in the codon, i.e., these SNPs (single nucleotide polymorphisms) do not change the coded aminoacids. Even the few ones that appear on the 1st position in the codon, when inspected, didn't cause the aminoacid to change.
#
# This deserves our attention and discussion. Maybe we are seeing adaptations in "codon usage".
#
# The array below shows where in the codon each SNP occur:
#
# - 0: 3rd position
# - 2: 2nd position
# - 1: 1st position

# %%
important = original_importances_sorted[original_importances_sorted > imp_threshold]
important_positions = important.index
nums = important_positions.values.astype('int')
resto = nums%3
df_codons = pd.Series(resto, index=important_positions)
df_codons

# %% [markdown]
# # SHAP importance

# %%
# load JS visualization code to notebook
shap.initjs()

# explain the model's predictions using SHAP values
# (same syntax works for LightGBM, CatBoost, and scikit-learn models)
explainer = shap.TreeExplainer(clf)
shap_values = explainer.shap_values(X)

# visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
#shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])

# %%
array_shap_values = np.array(shap_values)
array_shap_values.shape

# %%
explainer.expected_value

# %%
# visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
shap.force_plot(explainer.expected_value[1], array_shap_values[1][0,:], X.iloc[0,:])

# %% [markdown]
# # Combine one-hot encoding back to original attributes

# %%
print('shap_values is a table with {0} samples and {1} attributes'.format(shap_values[1].shape[0], shap_values[1].shape[1]))
cols = X.columns
print('X dataset has {0} columns (i.e. attributes)'.format(cols.shape[0]))

# %%
df_shap_values = pd.DataFrame(shap_values[1], index=X.index, columns=X.columns)
print('df_shap_values is a DataFrame with {0} samples and {1} columns'.format(df_shap_values.shape[0], df_shap_values.shape[1]))

# %%
list_shap_original = []

# %%
import re
pattern = "^\d+"
dic={}

# %%
for i, sample in df_shap_values.iterrows():
    dic = {}
    # The code below sums the importances for each category in each attribute.
    for pos in sample.index:
        attr = re.match(pattern, pos).group()
        if attr not in dic.keys():
            dic[attr] = sample[pos]
        else:
            dic[attr] += sample[pos]
    df_sample = pd.DataFrame(dic, index=[i])
    list_shap_original.append(df_sample)

# %%
shap_original = pd.concat(list_shap_original, axis=0)

# %%
shap_original.shape

# %%
data = df.drop('class', axis=1).values
data.shape
X_original = pd.DataFrame(data, index=shap_original.index, columns=shap_original.columns)
X_original.head()

# %% [markdown]
# Now the dataframe `shap_original` contains the shap values for the correct attributes.
#
# As suggested by SHAP's developer [here](https://github.com/slundberg/shap/issues/397), the values were summed for all categories in each attribute, for each sample.

# %% [markdown]
# # Sort attributes by importance
# ## Select the 30 most important ones

# %%
# Since shap values are positive or negative depending on which direction they push the result, I will take the abs value to determine the most important ones.
shap_abs = abs(shap_original)

# %%
# Here, I'll summ all abs shap values in each column.
# This way, I can have an idea of which columns have the largest overall effect.
# Then I'll select the 30 largest.
shap_sum = shap_abs.sum(axis=0)

# %%
max_imp = shap_sum.max()
original_index = shap_sum.index
loc = pd.Index(shap_sum).get_loc(max_imp)
max_pos = original_index[loc]

# %% [markdown]
# ### Select 30 most important

# %%
sorted_shap_sum = shap_sum.sort_values(ascending=False)
sorted_shap_sum.head()

# %%
best_shap = sorted_shap_sum[0:30]
best_shap.head()

# %%
cols = list(best_shap.index)

# %%
X_best_attrib = X_original.loc[:, cols]
X_best_attrib.head()

# %%
best_shap_values = shap_original[cols]
best_shap_values.iloc[0,:].values

# %%
X_best_attrib.iloc[0,:]

# %%
# visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
shap.force_plot(explainer.expected_value[1], best_shap_values.iloc[340,:].values, X_best_attrib.iloc[340,:])

# %% [markdown]
# # !!!Corrigir esse nome
# para a funcao shap.force_plot, o shap values deve ser um nd.numpy.array, ou seja, os valores somente.
#
# A variavel `best_shap_values` é um dataframe, preciso de um np.array

# %%
best_shap_values.head()
best_shap_values_values = best_shap_values.values

# %%
# visualize the training set predictions
shap.force_plot(explainer.expected_value[1], best_shap_values_values, X_best_attrib)

# %%
plt.scatter(np.linspace(1, 341, 341), best_shap_values.iloc[:,0]);

# %% [markdown]
# # stopped here

# %%
expect = explainer.expected_value[1]
expect

# %%
sp_v = shap_values[1][0,0:5]
sp_v

# %%
X_reduced = X.iloc[0,0:5]
X_reduced

# %%
# visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
shap.force_plot(expect, sp_v, X_reduced)

# %%
imp = shap_values[0][0]
col = X.columns
df_imp = pd.Series(imp, index=col)
df_imp = df_imp.sort_values(ascending=False)
df_imp

# %%
# The code below sums the importances for each category in each attribute.
for pos in df_imp.index:
    attr = re.match(pattern, pos).group()
    if attr not in dic.keys():
        dic[attr] = df_imp[pos]
    else:
        dic[attr] += df_imp[pos]

# %%
original_shap = pd.Series(dic)
original_shap_values = original_shap.values
original_X = X.loc[list(original_shap.index)]

# %%
original_shap

# %% [markdown]
# # Treat importance values from one-hot encoding to original attributes
#
# [Questions about SHAP handling categorical variables #397](https://github.com/slundberg/shap/issues/397)
#
# Hey!
#
# 1 - You should use SUM (assuming you don't want to break it out by category). Because that will measure the total effect of all the categories, and so capture the impact of that feature before one-hot encoding.
#
# 2 - I think sum is already a very well motivated way of computing the Shapley values for the group. The nice thing about Shapley values additivity is that it makes sense to let the credit of a group be the sum of the credit assigned to each member. A less-obvious feature is also to tell KernelExplainer to treat a whole group of features as a single entity by using the shap.common.DenseData object (which also makes the method faster). The only difference between summing up the credit of each feature and treating them all as a single "group feature" is that when credit for interaction effects is split evenly among the set of all participating features, the size of that set could change if you collapse some features to a single group.
